# %%
import numpy as np
import openfermion
from openfermion.chem import MolecularData
from openfermionqchem import run_qchem
import qeom

# %%
def print_result(bond,energy):   
    string1,string2 = "Total Energy\n","Excitation Energy\n"
    
    for i in range(len(bond)):
        string1 += "{:4.2f}".format(bond[i])
        string2 += "{:4.2f}".format(bond[i])

        for j in range(len(energy[i])):
            string1 += "{:15.10f}".format(energy[i][j])
        string1 += '\n'

        for j in range(1,len(energy[i])):
            string2 += "{:15.10f}".format((energy[i][j] - energy[i][0]) * 27.211324570273)
        string2 += '\n'
        
    print(string1+'\n'+string2)

# %% [markdown]
# ## H4/STO-3G

# %%
# Set molecule parameters.
# We do not run calculations through OpenFermion directly.
basis        = 'sto-3g'
multiplicity = 1

# Generate molecule at different bond lengths.
bond_length_interval = 0.05
n_points = 14
singlet  = []
triplet  = []
bond_lengths = []

for point in range(n_points):
    bond_length    = 1.75 + point * bond_length_interval
    geometry       = [('H', (0., 0., 0.)), ('H', (0., 0., bond_length))]
    molecule       = MolecularData(geometry, basis, multiplicity)
    directory      = "/Users/yongbinkim/Desktop/venv/publish/qeom-davidson/OpenFermion-QChem/examples/"
    system         = 'H4/eom-ccsd/sto-3g/'+str(round(bond_length,3)).ljust(4,"0")+'/'
    molecule       = run_qchem(molecule,file_directory=directory+system,output_name='test_qis')

    print("r = {:4.2f}".format(bond_length))
    bond_lengths.append(bond_length)
    
    # ground state
    gs = qeom.Adapt_VQE(molecule)
    gs.run()
    
    qeom_davidson = qeom.DavidsonVar(gs=gs)
    
    # singlet
    user_guess = [[[0,1,2,5],[0,1,3,4]],[[0,1,2,7],[0,1,3,6]],[[0,1,4,5]]]
    qeom_davidson.run(nroot=3,user_guess=user_guess,spin='singlet',level=3)
    singlet.append(qeom_davidson.energy)

    # triplet
    qeom_davidson.run(nroot=2,spin='triplet',level=3)
    triplet.append(qeom_davidson.energy)
    
singlet      = np.array(singlet)
triplet      = np.array(triplet)   
bond_lengths = np.array(bond_lengths)
# Out:
# r = 1.75
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -1.82952518     0.479      0.00
#       2     -1.87614865     0.443      0.00
#       3     -1.92577017     0.336      0.00
#       4     -1.94379515     0.151      0.00
#       5     -1.96292785     0.179      0.00
#       6     -1.96520436     0.036      0.00
#       7     -1.96526312     0.002     -0.00
#       8     -1.96526312*    0.000     -0.00
#  ------------------------------------------------
#  SCF energy                   = -1.76954677
#  ADAPT-VQE correlation energy = -0.19571635
#  ADAPT-VQE energy             = -1.96526312
#
#  ADAPT-VQE calculation: 32.90 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
#  -------------------------------------------------------------------------------------
#       Iter  Root  NVecs  ResNorm     Total energy (a.u.)    Excitation energy (eV.)
#  -------------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|11011000> + 0.70711|11100100>
#       1     1     2       0.0696      -1.5859952042           10.3203824456
#       2     1     4       0.0409      -1.5900739348           10.2093947860
#       3     1     6       0.0173      -1.5924626632           10.1443943206
#       4     1     8       0.0000      -1.5934387746           10.1178330359
#  Initial guess vectors
#  |b2> =  - 0.70711|11010010> + 0.70711|11100001>
#       1     3     2       0.0514      -1.3973527970           15.4535922183
#       2     3     4       0.0297      -1.4491151650           14.0450696216
#       3     3     6       0.0254      -1.4498535716           14.0249765997
#       4     3     8       0.0000      -1.4508286301           13.9984439661
#  Initial guess vectors
#  |b3> =  + 1.00000|11001100>
#       1     4     1       0.2686      -1.5207989031           12.0944601581
#       2     4     2       0.2816      -1.5846035137           10.3582521883
#       3     4     3       0.3180      -1.6326755506            9.0501483904
#       4     4     9       0.1028      -1.7954354177            4.6212368206
#       5     4    10       0.0000      -1.8081048826            4.2764838969
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.808105    4.276484   0.00  + 0.12200|00110011> - 0.41982|00111100> + 0.25665|01011010> - 0.18293|01100110> - 0.18293|10011001> + 0.25665|10100101> - 0.44544|11000011> + 0.63317|11001100>
#      2   -1.593439   10.117833   0.00  - 0.70264|11011000> + 0.70264|11100100>
#      3   -1.450829   13.998444   0.00  - 0.53902|01111000> + 0.53902|10110100> - 0.45582|11010010> + 0.45582|11100001>
#
#  qEOM-Davidson calculation: 30.42 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
#  -------------------------------------------------------------------------------------
#       Iter  Root  NVecs  ResNorm     Total energy (a.u.)    Excitation energy (eV.)
#  -------------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|11011000> + 0.70711|11100100>
#       1     1     2       0.2193      -1.7997906077            4.5027263313
#       2     1     4       0.0714      -1.9021325463            1.7178666223
#       3     1     6       0.0487      -1.9052097638            1.6341314582
#       4     1     8       0.0000      -1.9086345867            1.5409374918
#  Initial guess vectors
#  |b2> =  + 0.70711|01111000> + 0.70711|10110100>
#       1     2     2       0.2043      -1.6415581437            8.8084412669
#       2     2     4       0.0658      -1.8434999421            3.3133374462
#       3     2     6       0.0520      -1.8463264875            3.2364234024
#       4     2     8       0.0000      -1.8497950344            3.1420396466
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.908635    1.540937   2.00  - 0.31456|01110010> - 0.31456|10110001> + 0.62993|11011000> + 0.62993|11100100>
#      2   -1.849795    3.142040   2.00  + 0.49106|01111000> + 0.49106|10110100> - 0.50431|11010010> - 0.50431|11100001>
#
#  qEOM-Davidson calculation: 9.52 s
#  =====================================================================================
#
# r = 1.80
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -1.83585836     0.477      0.00
#       2     -1.88221628     0.444      0.00
#       3     -1.93165707     0.337      0.00
#       4     -1.94849654     0.153      0.00
#       5     -1.96725351     0.176      0.00
#       6     -1.96888992     0.030      0.00
#       7     -1.96891484     0.001      0.00
#       8     -1.96891484*    0.000      0.00
#  ------------------------------------------------
#  SCF energy                   = -1.77674732
#  ADAPT-VQE correlation energy = -0.19216752
#  ADAPT-VQE energy             = -1.96891484
#
#  ADAPT-VQE calculation: 33.01 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
#  -------------------------------------------------------------------------------------
#       Iter  Root  NVecs  ResNorm     Total energy (a.u.)    Excitation energy (eV.)
#  -------------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|11011000> + 0.70711|11100100>
#       1     1     2       0.0617      -1.5785960517           10.6210911876
#       2     1     4       0.0286      -1.5823157822           10.5198723931
#       3     1     6       0.0161      -1.5832877980           10.4934225560
#       4     1     8       0.0000      -1.5842023768           10.4685356543
#  Initial guess vectors
#  |b2> =  - 0.70711|11010010> + 0.70711|11100001>
#       1     2     2       0.0471      -1.4033617093           15.3894497521
#       2     2     4       0.0175      -1.4521166097           14.0627643331
#       3     2     6       0.0144      -1.4523911596           14.0552934686
#       4     2     8       0.0000      -1.4527064994           14.0467126536
#  Initial guess vectors
#  |b3> =  + 1.00000|11001100>
#       1     4     1       0.2812      -1.5047252966           12.6312122789
#       2     4     2       0.2871      -1.5752831438           10.7112397973
#       3     4     3       0.3202      -1.6280392946            9.2756750551
#       4     4     9       0.1182      -1.7890529891            4.8942791558
#       5     4    10       0.0000      -1.8064783277            4.4201126115
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.806478    4.420113   0.00  + 0.14531|00110011> - 0.42580|00111100> + 0.25883|01011010> - 0.17153|01100110> - 0.17153|10011001> + 0.25883|10100101> - 0.45149|11000011> + 0.62102|11001100>
#      2   -1.584202   10.468536   0.00  - 0.70376|11011000> + 0.70376|11100100>
#      3   -1.452706   14.046713   0.00  - 0.53665|01111000> + 0.53665|10110100> - 0.45981|11010010> + 0.45981|11100001>
#
#  qEOM-Davidson calculation: 22.49 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
#  -------------------------------------------------------------------------------------
#       Iter  Root  NVecs  ResNorm     Total energy (a.u.)    Excitation energy (eV.)
#  -------------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|11011000> + 0.70711|11100100>
#       1     1     2       0.2190      -1.7919251493            4.8161238702
#       2     1     4       0.0631      -1.9010664247            1.8462452024
#       3     1     6       0.0417      -1.9036525588            1.7758730669
#       4     1     8       0.0000      -1.9061520030            1.7078598803
#  Initial guess vectors
#  |b2> =  + 0.70711|11010010> + 0.70711|11100001>
#       1     2     2       0.2020      -1.6596153251            8.4164494413
#       2     2     4       0.0505      -1.8518606448            3.1851996511
#       3     2     6       0.0400      -1.8535036177            3.1404921824
#       4     2     8       0.0000      -1.8555538109            3.0847037075
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.906152    1.707860   2.00  - 0.32832|01110010> - 0.32832|10110001> + 0.62359|11011000> + 0.62359|11100100>
#      2   -1.855554    3.084704   2.00  - 0.49170|01111000> - 0.49170|10110100> + 0.50552|11010010> + 0.50552|11100001>
#
#  qEOM-Davidson calculation: 10.67 s
#  =====================================================================================
#
# r = 1.85
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -1.84130345     0.475      0.00
#       2     -1.88739947     0.445      0.00
#       3     -1.93670728     0.339      0.00
#       4     -1.95260564     0.154      0.00
#       5     -1.97113325     0.174      0.00
#       6     -1.97232818     0.026     -0.00
#       7     -1.97232818*    0.001     -0.00
#  ------------------------------------------------
#  SCF energy                   = -1.78300199
#  ADAPT-VQE correlation energy = -0.18932618
#  ADAPT-VQE energy             = -1.97232818
#
#  ADAPT-VQE calculation: 22.85 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
#  -------------------------------------------------------------------------------------
#       Iter  Root  NVecs  ResNorm     Total energy (a.u.)    Excitation energy (eV.)
#  -------------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|11011000> + 0.70711|11100100>
#       1     1     2       0.0608      -1.5704422480           10.9358484517
#       2     1     4       0.0109      -1.5746911883           10.8202291588
#       3     1     6       0.0046      -1.5750544495           10.8103443394
#       4     1     8       0.0000      -1.5750923343           10.8093134432
#  Initial guess vectors
#  |b2> =  - 0.70711|11010010> + 0.70711|11100001>
#       1     2     2       0.0441      -1.4081285612           15.3526188665
#       2     2     4       0.0072      -1.4536915583           14.1127893619
#       3     2     6       0.0051      -1.4537496688           14.1112080992
#       4     2     8       0.0000      -1.4537893517           14.1101282759
#  Initial guess vectors
#  |b3> =  + 1.00000|11001100>
#       1     4     1       0.3043      -1.4846723628           13.2697606375
#       2     4     2       0.2951      -1.5669697570           11.0303395322
#       3     4     3       0.3198      -1.6269935132            9.3970136192
#       4     4     9       0.1262      -1.7829871655            5.1522197172
#       5     4    10       0.0000      -1.8036770918            4.5892194159
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.803677    4.589219   0.00  + 0.16132|00110011> - 0.43054|00111100> + 0.25840|01011010> - 0.15628|01100110> - 0.10213|01101001> - 0.10213|10010110> - 0.15628|10011001> + 0.25840|10100101> - 0.45547|11000011> + 0.61475|11001100>
#      2   -1.575092   10.809313   0.00  - 0.70483|11011000> + 0.70483|11100100>
#      3   -1.453789   14.110128   0.00  - 0.53566|01111000> + 0.53566|10110100> - 0.46148|11010010> + 0.46148|11100001>
#
#  qEOM-Davidson calculation: 26.99 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
#  -------------------------------------------------------------------------------------
#       Iter  Root  NVecs  ResNorm     Total energy (a.u.)    Excitation energy (eV.)
#  -------------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|11011000> + 0.70711|11100100>
#       1     1     2       0.2220      -1.7810764002            5.2042141720
#       2     1     4       0.0592      -1.8994417884            1.9833351747
#       3     1     6       0.0359      -1.9020384793            1.9126757759
#       4     1     8       0.0000      -1.9038811061            1.8625354593
#  Initial guess vectors
#  |b2> =  + 0.70711|11010010> + 0.70711|11100001>
#       1     2     2       0.2035      -1.6635343246            8.4026897403
#       2     2     4       0.0363      -1.8585895988            3.0949773664
#       3     2     6       0.0289      -1.8594288115            3.0721412753
#       4     2     8       0.0000      -1.8604986391            3.0430298490
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.903881    1.862535   2.00  - 0.34476|01110010> - 0.34476|10110001> + 0.61500|11011000> + 0.61500|11100100>
#      2   -1.860499    3.043030   2.00  - 0.49177|01111000> - 0.49177|10110100> + 0.50674|11010010> + 0.50674|11100001>
#
#  qEOM-Davidson calculation: 9.70 s
#  =====================================================================================
#
# r = 1.90
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -1.84597414     0.473      0.00
#       2     -1.89181306     0.446      0.00
#       3     -1.94103129     0.340      0.00
#       4     -1.95616717     0.156      0.00
#       5     -1.97457552     0.172      0.00
#       6     -1.97546176     0.022     -0.00
#       7     -1.97546176*    0.000     -0.00
#  ------------------------------------------------
#  SCF energy                   = -1.78842885
#  ADAPT-VQE correlation energy = -0.18703291
#  ADAPT-VQE energy             = -1.97546176
#
#  ADAPT-VQE calculation: 21.71 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
#  -------------------------------------------------------------------------------------
#       Iter  Root  NVecs  ResNorm     Total energy (a.u.)    Excitation energy (eV.)
#  -------------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|11011000> + 0.70711|11100100>
#       1     1     2       0.0560      -1.5620900659           11.2483913125
#       2     1     4       0.0100      -1.5657529975           11.1487180901
#       3     1     6       0.0016      -1.5661530664           11.1378316876
#       4     1     8       0.0000      -1.5661577485           11.1377042815
#  Initial guess vectors
#  |b2> =  - 0.70711|11010010> + 0.70711|11100001>
#       1     2     2       0.0415      -1.4119680341           15.3334106433
#       2     2     4       0.0018      -1.4541919017           14.1844432778
#       3     2     6       0.0000      -1.4541959382           14.1843334398
#  Initial guess vectors
#  |b3> =  + 1.00000|11001100>
#       1     4     1       0.3121      -1.4665475532           13.8482296357
#       2     4     2       0.3005      -1.5532451287           11.4890737689
#       3     4     3       0.3257      -1.6155699789            9.7931320401
#       4     4     9       0.1378      -1.7758465805            5.4317934151
#       5     4    10       0.0000      -1.8012684418            4.7400308965
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.801268    4.740031   0.00  + 0.18109|00110011> - 0.43388|00111100> + 0.26223|01011010> - 0.15259|01100110> - 0.10964|01101001> - 0.10964|10010110> - 0.15259|10011001> + 0.26223|10100101> - 0.45892|11000011> + 0.60018|11001100>
#      2   -1.566158   11.137704   0.00  - 0.70503|11011000> + 0.70503|11100100>
#      3   -1.454196   14.184333   0.00  - 0.53387|01111000> + 0.53387|10110100> - 0.46366|11010010> + 0.46366|11100001>
#
#  qEOM-Davidson calculation: 17.55 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
#  -------------------------------------------------------------------------------------
#       Iter  Root  NVecs  ResNorm     Total energy (a.u.)    Excitation energy (eV.)
#  -------------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|11011000> + 0.70711|11100100>
#       1     1     2       0.2209      -1.7745846446            5.4661323626
#       2     1     4       0.0519      -1.8984047140            2.0968242659
#       3     1     6       0.0309      -1.9004780350            2.0404064543
#       4     1     8       0.0000      -1.9018315967            2.0035742467
#  Initial guess vectors
#  |b2> =  + 0.70711|11010010> + 0.70711|11100001>
#       1     2     2       0.2051      -1.6663141857            8.4123149595
#       2     2     4       0.0289      -1.8635286752            3.0458474756
#       3     2     6       0.0232      -1.8640547280            3.0315328829
#       4     2     8       0.0000      -1.8647399062            3.0128882768
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.901832    2.003574   2.00  - 0.35572|01110010> - 0.35572|10110001> + 0.60929|11011000> + 0.60929|11100100>
#      2   -1.864740    3.012888   2.00  - 0.49186|01111000> - 0.49186|10110100> + 0.50715|11010010> + 0.50715|11100001>
#
#  qEOM-Davidson calculation: 9.90 s
#  =====================================================================================
#
# r = 1.95
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -1.84997035     0.471      0.00
#       2     -1.89555788     0.447      0.00
#       3     -1.94472578     0.342      0.00
#       4     -1.95923341     0.157      0.00
#       5     -1.97760568     0.171      0.00
#       6     -1.97827282     0.020      0.00
#       7     -1.97827282*    0.000      0.00
#  ------------------------------------------------
#  SCF energy                   = -1.79313192
#  ADAPT-VQE correlation energy = -0.18514091
#  ADAPT-VQE energy             = -1.97827282
#
#  ADAPT-VQE calculation: 21.22 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
#  -------------------------------------------------------------------------------------
#       Iter  Root  NVecs  ResNorm     Total energy (a.u.)    Excitation energy (eV.)
#  -------------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|11011000> + 0.70711|11100100>
#       1     1     2       0.0520      -1.5538465840           11.5492001613
#       2     1     4       0.0096      -1.5570349795           11.4624396988
#       3     1     6       0.0000      -1.5574390023           11.4514457015
#  Initial guess vectors
#  |b2> =  - 0.70711|11010010> + 0.70711|11100001>
#       1     2     2       0.0391      -1.4150426017           15.3262403771
#       2     2     4       0.0047      -1.4539872860           14.2665039318
#       3     2     6       0.0029      -1.4540144071           14.2657659306
#       4     2     8       0.0000      -1.4540275783           14.2654075249
#  Initial guess vectors
#  |b3> =  + 1.00000|11001100>
#       1     4     1       0.3192      -1.4486118955           14.4127754276
#       2     4     2       0.3053      -1.5397199570           11.9336043940
#       3     4     3       0.3314      -1.6041571206           10.1801838213
#       4     4     9       0.1477      -1.7688387551            5.6989784140
#       5     4    10       0.0000      -1.7988444270            4.8824843390
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.798844    4.882484   0.00  + 0.19849|00110011> - 0.43771|00111100> + 0.26584|01011010> - 0.15030|01100110> - 0.11554|01101001> - 0.11554|10010110> - 0.15030|10011001> + 0.26584|10100101> - 0.46192|11000011> + 0.58517|11001100>
#      2   -1.557439   11.451446   0.00  - 0.70513|11011000> + 0.70513|11100100>
#      3   -1.454028   14.265408   0.00  - 0.53372|01111000> + 0.53372|10110100> - 0.46380|11010010> + 0.46380|11100001>
#
#  qEOM-Davidson calculation: 30.36 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
#  -------------------------------------------------------------------------------------
#       Iter  Root  NVecs  ResNorm     Total energy (a.u.)    Excitation energy (eV.)
#  -------------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|11011000> + 0.70711|11100100>
#       1     1     2       0.2204      -1.7679512441            5.7231287646
#       2     1     4       0.0457      -1.8973237508            2.2027314934
#       3     1     6       0.0268      -1.8989889023            2.1574205172
#       4     1     8       0.0000      -1.9000032996            2.1298174216
#  Initial guess vectors
#  |b2> =  + 0.70711|11010010> + 0.70711|11100001>
#       1     2     2       0.2068      -1.6683008109            8.4347490473
#       2     2     4       0.0231      -1.8675999440            3.0115556489
#       3     2     6       0.0187      -1.8679307396            3.0025542613
#       4     2     8       0.0000      -1.8683723968            2.9905361847
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.900003    2.129817   2.00  - 0.36651|01110010> - 0.36651|10110001> + 0.60324|11011000> + 0.60324|11100100>
#      2   -1.868372    2.990536   2.00  - 0.49193|01111000> - 0.49193|10110100> + 0.50740|11010010> + 0.50740|11100001>
#
#  qEOM-Davidson calculation: 7.72 s
#  =====================================================================================
#
# r = 2.00
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -1.85337994     0.470      0.00
#       2     -1.89872250     0.448      0.00
#       3     -1.94787535     0.343      0.00
#       4     -1.96185797     0.159      0.00
#       5     -1.98025718     0.171      0.00
#       6     -1.98076649     0.017      0.00
#       7     -1.98076649*    0.000      0.00
#  ------------------------------------------------
#  SCF energy                   = -1.79720283
#  ADAPT-VQE correlation energy = -0.18356365
#  ADAPT-VQE energy             = -1.98076649
#
#  ADAPT-VQE calculation: 21.36 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
#  -------------------------------------------------------------------------------------
#       Iter  Root  NVecs  ResNorm     Total energy (a.u.)    Excitation energy (eV.)
#  -------------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|11011000> + 0.70711|11100100>
#       1     1     2       0.0484      -1.5457780942           11.8366103652
#       2     1     4       0.0092      -1.5485803827           11.7603563835
#       3     1     6       0.0022      -1.5489614246           11.7499877288
#       4     1     8       0.0000      -1.5489702869           11.7497465732
#  Initial guess vectors
#  |b2> =  - 0.70711|11010010> + 0.70711|11100001>
#       1     2     2       0.0370      -1.4174789853           15.3277990605
#       2     2     4       0.0084      -1.4532410529           14.3546658299
#       3     2     6       0.0062      -1.4533121165           14.3527320957
#       4     2     8       0.0000      -1.4533739388           14.3510498286
#  Initial guess vectors
#  |b3> =  + 1.00000|11001100>
#       1     5     1       0.3258      -1.4310599049           14.9582442498
#       2     5     2       0.3095      -1.5266257538           12.3577709171
#       3     5     3       0.3366      -1.5930506594           10.5502612503
#       4     5     9       0.1560      -1.7621209371            5.9496350495
#       5     5    10       0.0000      -1.7965386119            5.0130845288
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.796539    5.013085   0.00  + 0.21491|00110011> - 0.44047|00111100> + 0.26886|01011010> - 0.14823|01100110> - 0.12064|01101001> - 0.12064|10010110> - 0.14823|10011001> + 0.26886|10100101> - 0.46417|11000011> + 0.57160|11001100>
#      2   -1.548970   11.749747   0.00  - 0.70525|11011000> + 0.70525|11100100>
#      3   -1.453374   14.351050   0.00  - 0.53337|01111000> + 0.53337|10110100> - 0.46410|11010010> + 0.46410|11100001>
#
#  qEOM-Davidson calculation: 22.01 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
#  -------------------------------------------------------------------------------------
#       Iter  Root  NVecs  ResNorm     Total energy (a.u.)    Excitation energy (eV.)
#  -------------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|11011000> + 0.70711|11100100>
#       1     1     2       0.2203      -1.7612769475            5.9726011244
#       2     1     4       0.0406      -1.8962639830            2.2994250866
#       3     1     6       0.0236      -1.8976115288            2.2627565817
#       4     1     8       0.0000      -1.8983881515            2.2416236503
#  Initial guess vectors
#  |b2> =  + 0.70711|11010010> + 0.70711|11100001>
#       1     2     2       0.2085      -1.6696411597            8.4661322889
#       2     2     4       0.0185      -1.8709852632            2.9872925368
#       3     2     6       0.0150      -1.8711991539            2.9814722880
#       4     2     8       0.0000      -1.8714791706            2.9738526620
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.898388    2.241624   2.00  - 0.37680|01110010> - 0.37680|10110001> + 0.59719|11011000> + 0.59719|11100100>
#      2   -1.871479    2.973853   2.00  - 0.49138|01111000> - 0.49138|10110100> + 0.50813|11010010> + 0.50813|11100001>
#
#  qEOM-Davidson calculation: 10.24 s
#  =====================================================================================
#
# r = 2.05
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -1.85627992     0.469      0.00
#       2     -1.90138448     0.449      0.00
#       3     -1.95055382     0.345      0.00
#       4     -1.96409241     0.160      0.00
#       5     -1.98256637     0.170      0.00
#       6     -1.98296032     0.015     -0.00
#       7     -1.98296032*    0.000     -0.00
#  ------------------------------------------------
#  SCF energy                   = -1.80072223
#  ADAPT-VQE correlation energy = -0.18223809
#  ADAPT-VQE energy             = -1.98296032
#
#  ADAPT-VQE calculation: 21.43 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
#  -------------------------------------------------------------------------------------
#       Iter  Root  NVecs  ResNorm     Total energy (a.u.)    Excitation energy (eV.)
#  -------------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|11011000> + 0.70711|11100100>
#       1     1     2       0.0453      -1.5379298344           12.1098689091
#       2     1     4       0.0088      -1.5404153776           12.0422339853
#       3     1     6       0.0034      -1.5407542891           12.0330117556
#       4     1     8       0.0000      -1.5407743534           12.0324657792
#  Initial guess vectors
#  |b2> =  - 0.70711|11010010> + 0.70711|11100001>
#       1     2     2       0.0350      -1.4193769599           15.3358496566
#       2     2     4       0.0112      -1.4520702252           14.4462226038
#       3     2     6       0.0088      -1.4521898324           14.4429679323
#       4     2     8       0.0000      -1.4523130152           14.4396159643
#  Initial guess vectors
#  |b3> =  + 1.00000|11001100>
#       1     5     1       0.3320      -1.4140222327           15.4815588757
#       2     5     2       0.3132      -1.5141014395           12.7582710960
#       3     5     3       0.3416      -1.5824241348           10.8991200597
#       4     5     9       0.1634      -1.7557735749            6.1820521801
#       5     5    10       0.0000      -1.7944201698            5.1304271433
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.794420    5.130427   0.00  + 0.22943|00110011> - 0.44357|00111100> + 0.27172|01011010> - 0.14705|01100110> - 0.12468|01101001> - 0.12468|10010110> - 0.14705|10011001> + 0.27172|10100101> - 0.46631|11000011> + 0.55782|11001100>
#      2   -1.540774   12.032466   0.00  - 0.70540|11011000> + 0.70540|11100100>
#      3   -1.452313   14.439616   0.00  - 0.53211|01111000> + 0.53211|10110100> - 0.46543|11010010> + 0.46543|11100001>
#
#  qEOM-Davidson calculation: 16.04 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
#  -------------------------------------------------------------------------------------
#       Iter  Root  NVecs  ResNorm     Total energy (a.u.)    Excitation energy (eV.)
#  -------------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|11011000> + 0.70711|11100100>
#       1     1     2       0.2205      -1.7546409444            6.2128725581
#       2     1     4       0.0363      -1.8952660365            2.3862775331
#       3     1     6       0.0209      -1.8963652503            2.3563664701
#       4     1     8       0.0000      -1.8969737395            2.3398086717
#  Initial guess vectors
#  |b2> =  + 0.70711|11010010> + 0.70711|11100001>
#       1     2     2       0.2104      -1.6704497654            8.5038260551
#       2     2     4       0.0148      -1.8738177287            2.9699143983
#       3     2     6       0.0119      -1.8739561648            2.9661473684
#       4     2     8       0.0000      -1.8741348891            2.9612840442
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.896974    2.339809   2.00  - 0.38613|01110010> - 0.38613|10110001> + 0.59142|11011000> + 0.59142|11100100>
#      2   -1.874135    2.961284   2.00  - 0.49221|01111000> - 0.49221|10110100> + 0.50745|11010010> + 0.50745|11100001>
#
#  qEOM-Davidson calculation: 7.54 s
#  =====================================================================================
#
# r = 2.10
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -1.85873791     0.468      0.00
#       2     -1.90361186     0.450      0.00
#       3     -1.95282568     0.346      0.00
#       4     -1.96598483     0.162      0.00
#       5     -1.98456967     0.170      0.00
#       6     -1.98487817     0.013      0.00
#       7     -1.98487817*    0.000      0.00
#  ------------------------------------------------
#  SCF energy                   = -1.80376100
#  ADAPT-VQE correlation energy = -0.18111716
#  ADAPT-VQE energy             = -1.98487817
#
#  ADAPT-VQE calculation: 21.33 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
#  -------------------------------------------------------------------------------------
#       Iter  Root  NVecs  ResNorm     Total energy (a.u.)    Excitation energy (eV.)
#  -------------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|11011000> + 0.70711|11100100>
#       1     1     2       0.0426      -1.5303326395           12.3687858278
#       2     1     4       0.0083      -1.5325559300           12.3082871458
#       3     1     6       0.0042      -1.5328399199           12.3005594061
#       4     1     8       0.0000      -1.5328707196           12.2997213048
#  Initial guess vectors
#  |b2> =  - 0.70711|11010010> + 0.70711|11100001>
#       1     2     2       0.0332      -1.4208176353           15.3488341521
#       2     2     4       0.0135      -1.4505629280           14.5394253367
#       3     2     6       0.0107      -1.4507282810           14.5349258629
#       4     2     8       0.0000      -1.4509122193           14.5299206577
#  Initial guess vectors
#  |b3> =  + 1.00000|11001100>
#       1     5     1       0.3377      -1.3975842790           15.9810445500
#       2     5     2       0.3165      -1.5022238680           13.1336627321
#       3     5     3       0.3463      -1.5723710678           11.2248645087
#       4     5     9       0.1697      -1.7498320664            6.3959156776
#       5     5    10       0.0000      -1.7925205157            5.2343064302
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.792521    5.234306   0.00  + 0.24302|00110011> - 0.44571|00111100> + 0.27426|01011010> - 0.14626|01100110> - 0.12800|01101001> - 0.12800|10010110> - 0.14626|10011001> + 0.27426|10100101> - 0.46837|11000011> + 0.54491|11001100>
#      2   -1.532871   12.299721   0.00  - 0.70558|11011000> + 0.70558|11100100>
#      3   -1.450912   14.529921   0.00  - 0.53169|01111000> + 0.53169|10110100> - 0.46581|11010010> + 0.46581|11100001>
#
#  qEOM-Davidson calculation: 32.56 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
#  -------------------------------------------------------------------------------------
#       Iter  Root  NVecs  ResNorm     Total energy (a.u.)    Excitation energy (eV.)
#  -------------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|11011000> + 0.70711|11100100>
#       1     1     2       0.2211      -1.7481037609            6.4429451588
#       2     1     4       0.0327      -1.8943513618            2.4633542253
#       3     1     6       0.0188      -1.8952573899            2.4387000003
#       4     1     8       0.0000      -1.8957441734            2.4254539748
#  Initial guess vectors
#  |b2> =  + 0.70711|11010010> + 0.70711|11100001>
#       1     2     2       0.2122      -1.6708184734            8.5459802017
#       2     2     4       0.0119      -1.8761963768            2.9573754135
#       3     2     6       0.0096      -1.8762860009            2.9549366230
#       4     2     8       0.0000      -1.8763994115            2.9518505700
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.895744    2.425454   2.00  - 0.39545|01110010> - 0.39545|10110001> + 0.58540|11011000> + 0.58540|11100100>
#      2   -1.876399    2.951851   2.00  - 0.49204|01111000> - 0.49204|10110100> + 0.50769|11010010> + 0.50769|11100001>
#
#  qEOM-Davidson calculation: 7.70 s
#  =====================================================================================
#
# r = 2.15
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -1.86081308     0.467      0.00
#       2     -1.90546409     0.451      0.00
#       3     -1.95474711     0.348      0.00
#       4     -1.96757908     0.163      0.00
#       5     -1.98630188     0.170      0.00
#       6     -1.98654626     0.012      0.00
#       7     -1.98654626*    0.000      0.00
#  ------------------------------------------------
#  SCF energy                   = -1.80638141
#  ADAPT-VQE correlation energy = -0.18016484
#  ADAPT-VQE energy             = -1.98654626
#
#  ADAPT-VQE calculation: 21.32 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
#  -------------------------------------------------------------------------------------
#       Iter  Root  NVecs  ResNorm     Total energy (a.u.)    Excitation energy (eV.)
#  -------------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|11011000> + 0.70711|11100100>
#       1     1     2       0.0401      -1.5230067395           12.6135242196
#       2     1     4       0.0077      -1.5250112970           12.5589775556
#       3     1     6       0.0047      -1.5252329169           12.5529469855
#       4     1     8       0.0000      -1.5252720656           12.5518816958
#  Initial guess vectors
#  |b2> =  - 0.70711|11010010> + 0.70711|11100001>
#       1     2     2       0.0314      -1.4218684670           15.3656305802
#       2     2     4       0.0152      -1.4487869015           14.6331443217
#       3     2     6       0.0121      -1.4489935402           14.6275214089
#       4     2     8       0.0000      -1.4492297550           14.6210936905
#  Initial guess vectors
#  |b3> =  + 1.00000|11001100>
#       1     5     1       0.3432      -1.3817984010           16.4559901525
#       2     5     2       0.3193      -1.4910259991           13.4837625273
#       3     5     3       0.3507      -1.5629338319           11.5270551500
#       4     5     9       0.1754      -1.7443026682            6.5917688785
#       5     5    10       0.0000      -1.7908445876            5.3253016035
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.790845    5.325302   0.00  + 0.25557|00110011> - 0.44790|00111100> + 0.27642|01011010> - 0.14569|01100110> - 0.13073|01101001> - 0.13073|10010110> - 0.14569|10011001> + 0.27642|10100101> - 0.46964|11000011> + 0.53297|11001100>
#      2   -1.525272   12.551882   0.00  - 0.70570|11011000> + 0.70570|11100100>
#      3   -1.449230   14.621094   0.00  - 0.53173|01111000> + 0.53173|10110100> - 0.46568|11010010> + 0.46568|11100001>
#
#  qEOM-Davidson calculation: 14.40 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
#  -------------------------------------------------------------------------------------
#       Iter  Root  NVecs  ResNorm     Total energy (a.u.)    Excitation energy (eV.)
#  -------------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|11011000> + 0.70711|11100100>
#       1     1     2       0.2218      -1.7417103926            6.6623081314
#       2     1     4       0.0296      -1.8935294580            2.5311102664
#       3     1     6       0.0170      -1.8942837171            2.5105858769
#       4     1     8       0.0000      -1.8946824646            2.4997354296
#  Initial guess vectors
#  |b2> =  + 0.70711|11010010> + 0.70711|11100001>
#       1     2     2       0.2140      -1.6708223868            8.5912646649
#       2     2     4       0.0095      -1.8781995131            2.9482583719
#       3     2     6       0.0076      -1.8782580213            2.9466662869
#       4     2     8       0.0000      -1.8783286279            2.9447449894
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
# ...
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -1.86522797     0.464      0.00
#       2     -1.90925821     0.454      0.00
#       3     -1.95886693     0.352      0.00
#       4     -1.97094662     0.167      0.00
#       5     -1.99018185     0.171      0.00
#       6     -1.99031122     0.009      0.00
#       7     -1.99031122*    0.000      0.00
#  ------------------------------------------------
#  SCF energy                   = -1.81224571
#  ADAPT-VQE correlation energy = -0.17806551
#  ADAPT-VQE energy             = -1.99031122
#
#  ADAPT-VQE calculation: 20.87 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
#  -------------------------------------------------------------------------------------
#       Iter  Root  NVecs  ResNorm     Total energy (a.u.)    Excitation energy (eV.)
#  -------------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|11011000> + 0.70711|11100100>
#       1     1     2       0.0342      -1.5027535610           13.2670897453
#       2     1     4       0.0060      -1.5042810577           13.2255245355
#       3     1     6       0.0024      -1.5043326365           13.2241210082
#       4     1     8       0.0000      -1.5043784727           13.2228737458
#  Initial guess vectors
#  |b2> =  - 0.70711|11010010> + 0.70711|11100001>
#       1     2     2       0.0264      -1.4232143007           15.4314583734
#       2     2     4       0.0186      -1.4238610283           15.4138600600
#       3     2     6       0.0161      -1.4425592955           14.9050554409
#       4     2     8       0.0000      -1.4429737500           14.8937775854
#  Initial guess vectors
#  |b3> =  + 1.00000|11001100>
#       1     5     1       0.3578      -1.3385587795           17.7350472361
#       2     5     2       0.3260      -1.4614750888           14.3903316506
#       3     5     8       0.2837      -1.6049224294           10.4869395058
#       4     5     9       0.1891      -1.7300503722            7.0820424424
#       5     5    10       0.0000      -1.7870374439            5.5313487386
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.787037    5.531349   0.00  + 0.28766|00110011> - 0.45280|00111100> + 0.28126|01011010> - 0.14460|01100110> - 0.13666|01101001> - 0.13666|10010110> - 0.14460|10011001> + 0.28126|10100101> - 0.47234|11000011> + 0.50174|11001100>
#      2   -1.504378   13.222874   0.00  - 0.70624|11011000> + 0.70624|11100100>
#      3   -1.442974   14.893778   0.00  - 0.52994|01111000> + 0.52994|10110100> - 0.46750|11010010> + 0.46750|11100001>
#
#  qEOM-Davidson calculation: 24.63 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
#  -------------------------------------------------------------------------------------
#       Iter  Root  NVecs  ResNorm     Total energy (a.u.)    Excitation energy (eV.)
#  -------------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|11011000> + 0.70711|11100100>
#       1     1     2       0.2249      -1.7236740682            7.2555501195
#       2     1     4       0.0230      -1.8916129242            2.6857113998
#       3     1     6       0.0136      -1.8920755915            2.6731216099
#       4     1     8       0.0000      -1.8923248009            2.6663402935
#  Initial guess vectors
#  |b2> =  + 0.70711|11010010> + 0.70711|11100001>
#       1     2     2       0.2194      -1.6692228254            8.7372405601
#       2     2     4       0.0046      -1.8825160370            2.9332497510
#       3     2     6       0.0036      -1.8825310566            2.9328410490
#       4     2     8       0.0000      -1.8825467072            2.9324151752
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.892325    2.666340   2.00  - 0.42637|01110010> - 0.42637|10110001> + 0.56367|11011000> + 0.56367|11100100>
#      2   -1.882547    2.932415   2.00  - 0.49311|01111000> - 0.49311|10110100> + 0.50678|11010010> + 0.50678|11100001>
#
#  qEOM-Davidson calculation: 7.19 s
#  =====================================================================================
#
# r = 2.35
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -1.86622843     0.464      0.00
#       2     -1.91006813     0.455      0.00
#       3     -1.95981582     0.354      0.00
#       4     -1.97170152     0.168      0.00
#       5     -1.99112525     0.171      0.00
#       6     -1.99123192     0.008      0.00
#       7     -1.99123192*    0.000      0.00
#  ------------------------------------------------
#  SCF energy                   = -1.81367520
#  ADAPT-VQE correlation energy = -0.17755672
#  ADAPT-VQE energy             = -1.99123192
#
#  ADAPT-VQE calculation: 20.85 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
#  -------------------------------------------------------------------------------------
#       Iter  Root  NVecs  ResNorm     Total energy (a.u.)    Excitation energy (eV.)
#  -------------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|11011000> + 0.70711|11100100>
#       1     1     2       0.0326      -1.4965851389           13.4599941789
#       2     1     4       0.0056      -1.4979957226           13.4216103288
#       3     1     6       0.0012      -1.4980472698           13.4202076605
#       4     1     8       0.0000      -1.4980589027           13.4198911127
#  Initial guess vectors
#  |b2> =  - 0.70711|11010010> + 0.70711|11100001>
#       1     2     2       0.0249      -1.4232029915           15.4568196093
#       2     2     4       0.0169      -1.4238262091           15.4398610314
#       3     2     6       0.0164      -1.4401783971           14.9948963370
#       4     2     8       0.0000      -1.4406120342           14.9830964968
#  Initial guess vectors
#  |b3> =  + 1.00000|11001100>
#       1     5     1       0.3622      -1.3255173450           18.1149754419
#       2     5     2       0.3277      -1.4528916880           14.6489508510
#       3     5     8       0.2863      -1.5994336248           10.6613506461
#       4     5     9       0.1928      -1.7260042561            7.2171961164
#       5     5    10       0.0000      -1.7861115551            5.5815968954
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.786112    5.581597   0.00  + 0.29662|00110011> - 0.45457|00111100> + 0.28231|01011010> - 0.14435|01100110> - 0.13797|01101001> - 0.13797|10010110> - 0.14435|10011001> + 0.28231|10100101> - 0.47269|11000011> + 0.49275|11001100>
#      2   -1.498059   13.419891   0.00  - 0.70637|11011000> + 0.70637|11100100>
#      3   -1.440612   14.983096   0.00  - 0.53106|01111000> + 0.53106|10110100> - 0.46621|11010010> + 0.46621|11100001>
#
#  qEOM-Davidson calculation: 19.47 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
#  -------------------------------------------------------------------------------------
#       Iter  Root  NVecs  ResNorm     Total energy (a.u.)    Excitation energy (eV.)
#  -------------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|11011000> + 0.70711|11100100>
#       1     1     2       0.2260      -1.7180960051            7.4323901015
#       2     1     4       0.0215      -1.8911366824            2.7237240698
#       3     1     6       0.0129      -1.8915379312            2.7128055567
#       4     1     8       0.0000      -1.8917598812            2.7067660041
#  Initial guess vectors
#  |b2> =  + 0.70711|11010010> + 0.70711|11100001>
#       1     2     2       0.2211      -1.6683024555            8.7873385422
#       2     2     4       0.0035      -1.8835306486            2.9306943221
#       3     2     6       0.0027      -1.8835398265            2.9304445805
#       4     2     8       0.0000      -1.8835485764            2.9302064847
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.891760    2.706766   2.00  - 0.43284|01110010> - 0.43284|10110001> + 0.55877|11011000> + 0.55877|11100100>
#      2   -1.883549    2.930206   2.00  - 0.49323|01111000> - 0.49323|10110100> + 0.50667|11010010> + 0.50667|11100001>
#
#  qEOM-Davidson calculation: 6.48 s
#  =====================================================================================
#
# r = 2.40
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -1.86704712     0.463      0.00
#       2     -1.91070454     0.457      0.00
#       3     -1.96060239     0.355      0.00
#       4     -1.97231550     0.169      0.00
#       5     -1.99193118     0.172      0.00
#       6     -1.99201991     0.007      0.00
#       7     -1.99201991*    0.000      0.00
#  ------------------------------------------------
#  SCF energy                   = -1.81489934
#  ADAPT-VQE correlation energy = -0.17712057
#  ADAPT-VQE energy             = -1.99201991
#
#  ADAPT-VQE calculation: 20.97 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
#  -------------------------------------------------------------------------------------
#       Iter  Root  NVecs  ResNorm     Total energy (a.u.)    Excitation energy (eV.)
#  -------------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|11011000> + 0.70711|11100100>
#       1     1     2       0.0312      -1.4907038361           13.6414743208
#       2     1     4       0.0053      -1.4920125078           13.6058636304
#       3     1     6       0.0000      -1.4920626538           13.6044990933
#  Initial guess vectors
#  |b2> =  - 0.70711|11010010> + 0.70711|11100001>
#       1     2     2       0.0235      -1.4230187741           15.4832745129
#       2     2     4       0.0153      -1.4236152480           15.4670436660
#       3     2     6       0.0167      -1.4377174534           15.0833039788
#       4     2     8       0.0000      -1.4381636676           15.0711619008
#  Initial guess vectors
#  |b3> =  + 1.00000|11001100>
#       1     6     1       0.3664      -1.3131411169           18.4731911045
#       2     6     2       0.3293      -1.4448855565           14.8882503994
#       3     6     8       0.2888      -1.5942788425           10.8230612060
#       4     6     9       0.1961      -1.7222694538            7.3402671392
#       5     6    10       0.0000      -1.7853237131            5.6244772234
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.785324    5.624477   0.00  + 0.30490|00110011> - 0.45545|00111100> + 0.28345|01011010> - 0.14432|01100110> - 0.13912|01101001> - 0.13912|10010110> - 0.14432|10011001> + 0.28345|10100101> - 0.47294|11000011> + 0.48465|11001100>
#      2   -1.492063   13.604499   0.00  - 0.70644|11011000> + 0.70644|11100100>
#      3   -1.438164   15.071162   0.00  - 0.53139|01111000> + 0.53139|10110100> - 0.46580|11010010> + 0.46580|11100001>
#
#  qEOM-Davidson calculation: 22.36 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
#  -------------------------------------------------------------------------------------
#       Iter  Root  NVecs  ResNorm     Total energy (a.u.)    Excitation energy (eV.)
#  -------------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|11011000> + 0.70711|11100100>
#       1     1     2       0.2272      -1.7127473713            7.5993756165
#       2     1     4       0.0202      -1.8907282959            2.7562789093
#       3     1     6       0.0123      -1.8910799142            2.7467109091
#       4     1     8       0.0000      -1.8912813112            2.7412306304
#  Initial guess vectors
#  |b2> =  + 0.70711|11010010> + 0.70711|11100001>
#       1     2     2       0.2228      -1.6672473013            8.8374927883
#       2     2     4       0.0027      -1.8843861153            2.9288580447
#       3     2     6       0.0020      -1.8843916351            2.9287078435
#       4     2     8       0.0000      -1.8843957574            2.9285956711
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.891281    2.741231   2.00  - 0.43870|01110010> - 0.43870|10110001> + 0.55422|11011000> + 0.55422|11100100>
#      2   -1.884396    2.928596   2.00  - 0.49353|01111000> - 0.49353|10110100> + 0.50638|11010010> + 0.50638|11100001>
#
#  qEOM-Davidson calculation: 4.40 s
#  =====================================================================================

# %%
print("singlet")
print_result(bond_lengths,singlet)
# Out:
# singlet
# Total Energy
# 1.75  -1.9652631233  -1.8081048826  -1.5934387746  -1.4508286301
# 1.80  -1.9689148382  -1.8064783277  -1.5842023768  -1.4527064994
# 1.85  -1.9723281769  -1.8036770918  -1.5750923343  -1.4537893517
# 1.90  -1.9754617591  -1.8012684418  -1.5661577485  -1.4541959382
# 1.95  -1.9782728236  -1.7988444270  -1.5574390023  -1.4540275783
# 2.00  -1.9807664879  -1.7965386119  -1.5489702869  -1.4533739388
# 2.05  -1.9829603171  -1.7944201698  -1.5407743534  -1.4523130152
# 2.10  -1.9848781650  -1.7925205157  -1.5328707196  -1.4509122193
# 2.15  -1.9865462555  -1.7908445876  -1.5252720656  -1.4492297550
# 2.20  -1.9879911055  -1.7893839707  -1.5179867419  -1.4473149703
# 2.25  -1.9892381735  -1.7881211263  -1.5110216589  -1.4452197026
# 2.30  -1.9903112215  -1.7870374439  -1.5043784727  -1.4429737500
# 2.35  -1.9912319226  -1.7861115551  -1.4980589027  -1.4406120342
# 2.40  -1.9920199071  -1.7853237131  -1.4920626538  -1.4381636676
#
# Excitation Energy
# 1.75   4.2764838969  10.1178330359  13.9984439661
# 1.80   4.4201126115  10.4685356543  14.0467126536
# 1.85   4.5892194159  10.8093134432  14.1101282759
# 1.90   4.7400308965  11.1377042815  14.1843334398
# 1.95   4.8824843390  11.4514457015  14.2654075249
# 2.00   5.0130845288  11.7497465732  14.3510498286
# 2.05   5.1304271433  12.0324657792  14.4396159643
# 2.10   5.2343064302  12.2997213048  14.5299206577
# 2.15   5.3253016035  12.5518816958  14.6210936905
# 2.20   5.4043632077  12.7894412886  14.7125138031
# 2.25   5.4726612482  13.0129047958  14.8034631864
# 2.30   5.5313487386  13.2228737458  14.8937775854
# 2.35   5.5815968954  13.4198911127  14.9830964968
# 2.40   5.6244772234  13.6044990933  15.0711619008

# %%
print("triplet")
print_result(bond_lengths,triplet)
# Out:
# triplet
# Total Energy
# 1.75  -1.9652631233  -1.9086345867  -1.8497950344
# 1.80  -1.9689148382  -1.9061520030  -1.8555538109
# 1.85  -1.9723281769  -1.9038811061  -1.8604986391
# 1.90  -1.9754617591  -1.9018315967  -1.8647399062
# 1.95  -1.9782728236  -1.9000032996  -1.8683723968
# 2.00  -1.9807664879  -1.8983881515  -1.8714791706
# 2.05  -1.9829603171  -1.8969737395  -1.8741348891
# 2.10  -1.9848781650  -1.8957441734  -1.8763994115
# 2.15  -1.9865462555  -1.8946824646  -1.8783286279
# 2.20  -1.9879911055  -1.8937703741  -1.8799696275
# 2.25  -1.9892381735  -1.8929894924  -1.8813639775
# 2.30  -1.9903112215  -1.8923248009  -1.8825467072
# 2.35  -1.9912319226  -1.8917598812  -1.8835485764
# 2.40  -1.9920199071  -1.8912813112  -1.8843957574
#
# Excitation Energy
# 1.75   1.5409374918   3.1420396466
# 1.80   1.7078598803   3.0847037075
# 1.85   1.8625354593   3.0430298490
# 1.90   2.0035742467   3.0128882768
# 1.95   2.1298174216   2.9905361847
# 2.00   2.2416236503   2.9738526620
# 2.05   2.3398086717   2.9612840442
# 2.10   2.4254539748   2.9518505700
# 2.15   2.4997354296   2.9447449894
# 2.20   2.5638709042   2.9394074982
# 2.25   2.6190541009   2.9353997614
# 2.30   2.6663402935   2.9324151752
# 2.35   2.7067660041   2.9302064847
# 2.40   2.7412306304   2.9285956711

# %%
fci_energies = np.array([[-1.965263123,-1.908634752,-1.849795572,-1.818602242,-1.593438758,-1.450829873],
                         [-1.968914838,-1.906152050,-1.855553805,-1.813583235,-1.584203258,-1.452706681],
                         [-1.972338803,-1.903881184,-1.860498878,-1.809010509,-1.575092604,-1.453789849],
                         [-1.975466301,-1.901831712,-1.864740139,-1.804939588,-1.566157831,-1.454196242],
                         [-1.978274757,-1.900003261,-1.868372947,-1.801371968,-1.557439766,-1.454028039],
                         [-1.980767298,-1.898388234,-1.871480470,-1.798280085,-1.548970554,-1.453374521],
                         [-1.982960646,-1.896973923,-1.874135029,-1.795622094,-1.540774819,-1.452313431],
                         [-1.984878291,-1.895744554,-1.876399589,-1.793350847,-1.532870971,-1.450912492],
                         [-1.986546299,-1.894682638,-1.878328745,-1.791418790,-1.525272127,-1.449230438],
                         [-1.987991118,-1.893770289,-1.879969925,-1.789780942,-1.517987213,-1.447318252],
                         [-1.989238176,-1.892989944,-1.881364149,-1.788396124,-1.511021751,-1.445219994],
                         [-1.990311222,-1.892325015,-1.882546933,-1.787227656,-1.504378706,-1.442973732],
                         [-1.991231923,-1.891760110,-1.883548845,-1.786243226,-1.498059111,-1.440612182],
                         [-1.992019909,-1.891281399,-1.884396320,-1.785414899,-1.492062858,-1.438163580]])

# %%
# Plot.
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(0)
plt.plot(bond_lengths, fci_energies[:,0], '--', label='GS', color='black')
plt.plot(bond_lengths, fci_energies[:,1], '--', label='T1', color='red')
plt.plot(bond_lengths, fci_energies[:,2], '--', label='T2', color='green')
plt.plot(bond_lengths, fci_energies[:,3], '--', label='S1', color='blue')
plt.plot(bond_lengths, fci_energies[:,4], '--', label='S2', color='orange')
plt.plot(bond_lengths, fci_energies[:,5], '--', label='S3', color='brown')

plt.plot(bond_lengths, triplet[:,0], 'o', label='GS', color='black')
plt.plot(bond_lengths, triplet[:,1], 'o', label='T1', color='red')
plt.plot(bond_lengths, triplet[:,2], 'o', label='T2', color='green')
plt.plot(bond_lengths, singlet[:,1], 'o', label='S1', color='blue')
plt.plot(bond_lengths, singlet[:,2], 'o', label='S2', color='orange')
plt.plot(bond_lengths, singlet[:,3], 'o', label='S3', color='brown')

plt.ylabel('Energy in Hartree')
plt.xlabel('Bond length in angstrom')
plt.legend()
plt.show()

# %%
# Plot.
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(0)
plt.plot(bond_lengths, abs(fci_energies[:,1]-triplet[:,1])*1000, 'o', label='T1', color='red')
plt.plot(bond_lengths, abs(fci_energies[:,2]-triplet[:,2])*1000, 'o', label='T2', color='green')
plt.plot(bond_lengths, abs(fci_energies[:,3]-singlet[:,1])*1000, 'o', label='S1', color='blue')
plt.plot(bond_lengths, abs(fci_energies[:,4]-singlet[:,2])*1000, 'o', label='S2', color='orange')
plt.plot(bond_lengths, abs(fci_energies[:,5]-singlet[:,3])*1000, 'o', label='S3', color='brown')

plt.ylabel('Error in mHartree')
plt.xlabel('Bond length in angstrom')
plt.legend()
plt.show()
