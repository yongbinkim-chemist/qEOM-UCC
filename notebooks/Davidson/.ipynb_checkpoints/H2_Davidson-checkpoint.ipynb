# %%
import numpy as np
import openfermion
from openfermion.chem import MolecularData
from openfermionqchem import run_qchem
import qeom

# %%
def print_result(bond,energy):   
    string1,string2 = "Total Energy\n","Excitation Energy\n"
    
    for i in range(len(bond)):
        string1 += "{:4.2f}".format(bond[i])
        string2 += "{:4.2f}".format(bond[i])

        for j in range(len(energy[i])):
            string1 += "{:15.10f}".format(energy[i][j])
        string1 += '\n'

        for j in range(1,len(energy[i])):
            string2 += "{:15.10f}".format((energy[i][j] - energy[i][0]) * 27.211324570273)
        string2 += '\n'
        
    print(string1+'\n'+string2)

# %% [markdown]
# ## H2/6-31G

# %%
# Set molecule parameters.
# We do not run calculations through OpenFermion directly.
basis        = 'sto-3g'
multiplicity = 1

# Generate molecule at different bond lengths.
bond_length_interval = 0.1
n_points = 19
singlet  = []
triplet  = []
bond_lengths = []

for point in range(n_points):
    bond_length    = 0.2 + point * bond_length_interval
    geometry       = [('H', (0., 0., 0.)), ('H', (0., 0., bond_length))]
    molecule       = MolecularData(geometry, basis, multiplicity)  
    directory      = "/Users/yongbinkim/Desktop/venv/publish/qeom-davidson/OpenFermion-QChem/examples/"
    system         = 'H2/eom-ccsd/6-31g/'+str(round(bond_length,2))+'/'
    molecule       = run_qchem(molecule,file_directory=directory+system,output_name='test_qis')
    
    print("r = {:4.2f}".format(bond_length))
    bond_lengths.append(bond_length)

    # ground state
    gs = qeom.Adapt_VQE(molecule)
    gs.run()
    
    qeom_davidson = qeom.Davidson(gs=gs)
    
    # singlet
    qeom_davidson.run(nroot=2,spin='singlet')
    singlet.append(qeom_davidson.energy)

    # triplet
    qeom_davidson.run(nroot=3,spin='triplet')
    triplet.append(qeom_davidson.energy)
    
singlet      = np.array(singlet)
triplet      = np.array(triplet)
bond_lengths = np.array(bond_lengths)
# Out:
# r = 0.20
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     0.07284297     0.322      0.00
#       2     0.06750959     0.195      0.00
#       3     0.06574922     0.125      0.00
#       4     0.06521597     0.048      0.00
#       5     0.06516888     0.014      0.00
#       6     0.06516888*    0.000      0.00
#  ------------------------------------------------
#  SCF energy                   = 0.07807279
#  ADAPT-VQE correlation energy = -0.01290391
#  ADAPT-VQE energy             = 0.06516888
#
#  ADAPT-VQE calculation: 16.60 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|01100000> + 0.70711|10010000>
#  |b2> =  - 0.70711|01001000> + 0.70711|10000100>
#      1      2      0.3331      0.8987175514      1.1282959251
#      2      4      0.2028      0.8561690816      1.1025648292
#      3      6      0.0113      0.8551417045      1.0892198128
#      4      8      0.0027      0.8551218207      1.0891913173
#      5      9      0.0000      0.8551218207      1.0891847630
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1    0.855122   21.495666   0.00  - 0.12715|00011000> + 0.12715|00100100> - 0.69557|01100000> + 0.69557|10010000>
#      2    1.089185   27.864829   0.00  - 0.17416|00001100> + 0.69557|01001000> - 0.69557|10000100>
#
#  qEOM-Davidson calculation: 0.19 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|01100000> + 0.70711|10010000>
#  |b2> =  + 0.70711|01001000> + 0.70711|10000100>
#  |b3> =  + 0.70711|00011000> + 0.70711|00100100>
#      1      3      0.2066      0.8110476507      0.9108675369      2.0636580334
#      2      6      0.0000      0.8030234137      0.9101295704      2.0526329706
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1    0.803023   20.077999   2.00  + 0.69948|01100000> + 0.69948|10010000>
#      2    0.910130   22.992500   2.00  + 0.70702|01001000> + 0.70702|10000100>
#      3    2.052633   54.081530   2.00  - 0.69895|00011000> - 0.69895|00100100>
#
#  qEOM-Davidson calculation: 0.07 s
#  =====================================================================================
#
# r = 0.30
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -0.65104431     0.325      0.00
#       2     -0.65720847     0.209      0.00
#       3     -0.65960709     0.136      0.00
#       4     -0.66047803     0.057      0.00
#       5     -0.66051018     0.012      0.00
#       6     -0.66051018*    0.000      0.00
#  ------------------------------------------------
#  SCF energy                   = -0.64515473
#  ADAPT-VQE correlation energy = -0.01535544
#  ADAPT-VQE energy             = -0.66051018
#
#  ADAPT-VQE calculation: 17.03 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|01100000> + 0.70711|10010000>
#  |b2> =  - 0.70711|01001000> + 0.70711|10000100>
#      1      2      0.3214      0.1210896231      0.3958334666
#      2      4      0.1717      0.0789078242      0.3718888272
#      3      6      0.0170      0.0774304154      0.3601167750
#      4      8      0.0000      0.0774023404      0.3600200869
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1    0.077402   20.079577   0.00  - 0.13129|00011000> + 0.13129|00100100> - 0.69481|01100000> + 0.69481|10010000>
#      2    0.360020   27.769980   0.00  - 0.16603|00001100> + 0.69610|01001000> - 0.69610|10000100>
#
#  qEOM-Davidson calculation: 0.14 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|01100000> + 0.70711|10010000>
#  |b2> =  + 0.70711|01001000> + 0.70711|10000100>
#  |b3> =  + 0.70711|00011000> + 0.70711|00100100>
#      1      3      0.2045      0.0222846127      0.1661793487      1.2125087171
#      2      6      0.0000      0.0119056320      0.1652016670      1.1995968039
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1    0.011906   18.297325   2.00  + 0.69884|01100000> + 0.69884|10010000>
#      2    0.165202   22.468713   2.00  + 0.70697|01001000> + 0.70697|10000100>
#      3    1.199597   50.615975   2.00  - 0.69814|00011000> - 0.69814|00100100>
#
#  qEOM-Davidson calculation: 0.07 s
#  =====================================================================================
#
# r = 0.40
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -0.93936820     0.326      0.00
#       2     -0.94601873     0.221      0.00
#       3     -0.94922168     0.149      0.00
#       4     -0.95066607     0.070      0.00
#       5     -0.95067865     0.007      0.00
#       6     -0.95067865*    0.000      0.00
#  ------------------------------------------------
#  SCF energy                   = -0.93300420
#  ADAPT-VQE correlation energy = -0.01767445
#  ADAPT-VQE energy             = -0.95067865
#
#  ADAPT-VQE calculation: 16.76 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|01100000> + 0.70711|10010000>
#  |b2> =  - 0.70711|01001000> + 0.70711|10000100>
#      1      2      0.3060     -0.2200242251      0.1010935652
#      2      4      0.1447     -0.2590971376      0.0789625620
#      3      6      0.0227     -0.2611814138      0.0694293542
#      4      8      0.0049     -0.2612218701      0.0691781938
#      5      9      0.0000     -0.2612218701      0.0691421811
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -0.261222   18.761032   0.00  + 0.13130|00011000> - 0.13130|00100100> - 0.69479|01100000> + 0.69479|10010000>
#      2    0.069142   27.750676   0.00  - 0.14984|00001100> - 0.69704|01001000> + 0.69704|10000100>
#
#  qEOM-Davidson calculation: 0.18 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|01100000> + 0.70711|10010000>
#  |b2> =  + 0.70711|01001000> + 0.70711|10000100>
#  |b3> =  + 0.70711|00011000> + 0.70711|00100100>
#      1      3      0.2029     -0.3313705224     -0.1344280209      0.8052947960
#      2      6      0.0000     -0.3444728631     -0.1357272694      0.7908583291
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -0.344473   16.495662   2.00  + 0.69840|01100000> + 0.69840|10010000>
#      2   -0.135727   22.175907   2.00  + 0.70688|01001000> + 0.70688|10000100>
#      3    0.790858   47.389528   2.00  + 0.69744|00011000> + 0.69744|00100100>
#
#  qEOM-Davidson calculation: 0.07 s
#  =====================================================================================
#
# r = 0.50
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -1.06465411     0.325      0.00
#       2     -1.07135787     0.230      0.00
#       3     -1.07550111     0.163      0.00
#       4     -1.07786349     0.084      0.00
#       5     -1.07786390     0.001      0.00
#       6     -1.07786390*    0.000      0.00
#  ------------------------------------------------
#  SCF energy                   = -1.05802481
#  ADAPT-VQE correlation energy = -0.01983908
#  ADAPT-VQE energy             = -1.07786390
#
#  ADAPT-VQE calculation: 16.66 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|01100000> + 0.70711|10010000>
#  |b2> =  - 0.70711|01001000> + 0.70711|10000100>
#      1      2      0.2904     -0.3948462277     -0.0258746969
#      2      4      0.1234     -0.4285910704     -0.0474778836
#      3      6      0.0256     -0.4312822673     -0.0544972964
#      4      8      0.0090     -0.4313412469     -0.0549530810
#      5      9      0.0000     -0.4313412469     -0.0550981821
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -0.431341   17.592738   0.00  + 0.12630|00011000> - 0.12630|00100100> - 0.69563|01100000> + 0.69563|10010000>
#      2   -0.055098   27.830810   0.00  - 0.12854|00001100> - 0.69776|01001000> + 0.69776|10000100>
#
#  qEOM-Davidson calculation: 0.18 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|01100000> + 0.70711|10010000>
#  |b2> =  + 0.70711|01001000> + 0.70711|10000100>
#  |b3> =  + 0.70711|00011000> + 0.70711|00100100>
#      1      3      0.2018     -0.5204270101     -0.2611563973      0.5777170241
#      2      6      0.0000     -0.5364842844     -0.2628944376      0.5621976777
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -0.536484   14.731656   2.00  + 0.69800|01100000> + 0.69800|10010000>
#      2   -0.262894   22.176399   2.00  + 0.70674|01001000> + 0.70674|10000100>
#      3    0.562198   44.628248   2.00  - 0.69617|00011000> - 0.69617|00100100>
#
#  qEOM-Davidson calculation: 0.07 s
#  =====================================================================================
#
# r = 0.60
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -1.11668426     0.322      0.00
#       2     -1.12305411     0.237      0.00
#       3     -1.12819535     0.176      0.00
#       4     -1.13194543     0.101      0.00
#       5     -1.13195346     0.006      0.00
#       6     -1.13195346*    0.000      0.00
#  ------------------------------------------------
#  SCF energy                   = -1.11003090
#  ADAPT-VQE correlation energy = -0.02192256
#  ADAPT-VQE energy             = -1.13195346
#
#  ADAPT-VQE calculation: 16.53 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|01100000> + 0.70711|10010000>
#  |b2> =  - 0.70711|01001000> + 0.70711|10000100>
#      1      2      0.2777     -0.4927512346     -0.0728286123
#      2      4      0.1075     -0.5199746988     -0.0959266599
#      3      6      0.0234     -0.5230551394     -0.1008460139
#      4      8      0.0121     -0.5231360248     -0.1014070648
#      5      9      0.0000     -0.5231360248     -0.1017376424
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -0.523136   16.566729   0.00  + 0.11591|00011000> - 0.11591|00100100> - 0.69723|01100000> + 0.69723|10010000>
#      2   -0.101738   28.033537   0.00  - 0.10476|00001100> - 0.69751|01001000> + 0.69751|10000100>
#
#  qEOM-Davidson calculation: 0.18 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|01100000> + 0.70711|10010000>
#  |b2> =  + 0.70711|01001000> + 0.70711|10000100>
#  |b3> =  + 0.70711|00011000> + 0.70711|00100100>
#      1      3      0.2006     -0.6345774278     -0.3030653903      0.4426288613
#      2      6      0.0000     -0.6534749317     -0.3054086879      0.4261057883
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -0.653475   13.020034   2.00  + 0.69756|01100000> + 0.69756|10010000>
#      2   -0.305409   22.491378   2.00  + 0.70651|01001000> + 0.70651|10000100>
#      3    0.426106   42.396856   2.00  - 0.67771|00011000> - 0.67771|00100100> + 0.18518|01000010> + 0.18518|10000001>
#
#  qEOM-Davidson calculation: 0.07 s
#  =====================================================================================
#
# r = 0.70
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -1.13255249     0.318      0.00
#       2     -1.13866520     0.243      0.00
#       3     -1.14439639     0.193      0.00
#       4     -1.15011234     0.118      0.00
#       5     -1.15015684     0.014      0.00
#       6     -1.15015684*    0.000      0.00
#  ------------------------------------------------
#  SCF energy                   = -1.12612316
#  ADAPT-VQE correlation energy = -0.02403368
#  ADAPT-VQE energy             = -1.15015684
#
#  ADAPT-VQE calculation: 16.59 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|01100000> + 0.70711|10010000>
#  |b2> =  - 0.70711|01001000> + 0.70711|10000100>
#      1      2      0.2699     -0.5510702819     -0.0766177487
#      2      4      0.0963     -0.5718386817     -0.1036946025
#      3      6      0.0162     -0.5748700017     -0.1075642786
#      4      8      0.0115     -0.5749665977     -0.1078936333
#      5      9      0.0000     -0.5749665977     -0.1083760327
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -0.574967   15.651688   0.00  - 0.10036|00011000> + 0.10036|00100100> + 0.69932|01100000> - 0.69932|10010000>
#      2   -0.108376   28.348236   0.00  - 0.11392|00110000> - 0.69555|01001000> + 0.69555|10000100>
#
#  qEOM-Davidson calculation: 0.21 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|01100000> + 0.70711|10010000>
#  |b2> =  + 0.70711|01001000> + 0.70711|10000100>
#  |b3> =  + 0.70711|00011000> + 0.70711|00100100>
#      1      3      0.1994     -0.7109811167     -0.2983727386      0.3622331531
#      2      6      0.0000     -0.7321053322     -0.3015536302      0.2738968018
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -0.732105   11.375735   2.00  + 0.69714|01100000> + 0.69714|10010000>
#      2   -0.301554   23.091617   2.00  - 0.70612|01001000> - 0.70612|10000100>
#      3    0.273897   38.750386   2.00  + 0.69585|01000010> - 0.10092|01100000> + 0.69585|10000001> - 0.10092|10010000>
#
#  qEOM-Davidson calculation: 0.07 s
#  =====================================================================================
#
# r = 0.80
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -1.12971841     0.313      0.00
#       2     -1.13667661     0.247      0.00
#       3     -1.14158984     0.197      0.00
#       4     -1.14991244     0.135      0.00
#       5     -1.15002788     0.023      0.00
#       6     -1.15002788*    0.000      0.00
#  ------------------------------------------------
#  SCF energy                   = -1.12371294
#  ADAPT-VQE correlation energy = -0.02631495
#  ADAPT-VQE energy             = -1.15002788
#
#  ADAPT-VQE calculation: 15.84 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|01100000> + 0.70711|10010000>
#  |b2> =  - 0.70711|01001000> + 0.70711|10000100>
#      1      2      0.2680     -0.5875828854     -0.0556862617
#      2      4      0.0906     -0.6030653388     -0.0896641755
#      3      6      0.0102     -0.6055308103     -0.0939997279
#      4      8      0.0045     -0.6056249916     -0.0940255269
#      5      9      0.0000     -0.6056249916     -0.1147564606
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -0.605625   14.813924   0.00  + 0.70148|01100000> - 0.70148|10010000>
#      2   -0.114756   28.171107   0.00  - 0.15465|00010010> + 0.15465|00100001> - 0.96951|00110000>
#
#  qEOM-Davidson calculation: 0.18 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|01100000> + 0.70711|10010000>
#  |b2> =  + 0.70711|01001000> + 0.70711|10000100>
#  |b3> =  + 0.70711|01000010> + 0.70711|10000001>
#      1      3      0.1429     -0.7821196002     -0.2668148848      0.1670762270
#      2      6      0.0000     -0.7890797943     -0.2711633104      0.1576054980
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -0.789080    9.821876   2.00  + 0.10641|01000010> - 0.69693|01100000> + 0.10641|10000001> - 0.69693|10010000>
#      2   -0.271163   23.915069   2.00  + 0.70545|01001000> + 0.70545|10000100>
#      3    0.157605   35.582436   2.00  - 0.69185|01000010> - 0.10953|01100000> - 0.69185|10000001> - 0.10953|10010000>
#
#  qEOM-Davidson calculation: 0.07 s
#  =====================================================================================
#
# r = 0.90
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -1.11715144     0.307      0.00
#       2     -1.12472330     0.250      0.00
#       3     -1.13670172     0.200      0.00
#       4     -1.14037709     0.127      0.00
#       5     -1.14060245     0.032      0.00
#       6     -1.14060245*    0.000      0.00
#  ------------------------------------------------
#  SCF energy                   = -1.11168637
#  ADAPT-VQE correlation energy = -0.02891608
#  ADAPT-VQE energy             = -1.14060245
#
#  ADAPT-VQE calculation: 15.85 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|01100000> + 0.70711|10010000>
#  |b2> =  + 1.00000|00110000>
#      1      2      0.2481     -0.6114423915     -0.1777886698
#      2      4      0.0812     -0.6233906731     -0.2140951307
#      3      6      0.0196     -0.6249659569     -0.2176768611
#      4      8      0.0050     -0.6250360756     -0.2196109190
#      5      9      0.0000     -0.6250360756     -0.2196340586
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -0.625036   14.029244   0.00  - 0.70333|01100000> + 0.70333|10010000>
#      2   -0.219634   25.060770   0.00  + 0.14690|00010010> - 0.14690|00100001> + 0.97044|00110000>
#
#  qEOM-Davidson calculation: 0.18 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|01100000> + 0.70711|10010000>
#  |b2> =  + 0.70711|01001000> + 0.70711|10000100>
#  |b3> =  + 0.70711|01000010> + 0.70711|10000001>
#      1      3      0.1357     -0.8272860477     -0.2203715246      0.0914637740
#      2      6      0.0000     -0.8325088100     -0.2263638991      0.0808021211
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -0.832509    8.383636   2.00  + 0.10929|01000010> - 0.69703|01100000> + 0.10929|10000001> - 0.69703|10010000>
#      2   -0.226364   24.877642   2.00  + 0.70429|01001000> + 0.70429|10000100>
#      3    0.080802   33.236036   2.00  - 0.68888|01000010> - 0.11298|01100000> - 0.68888|10000001> - 0.11298|10010000>
#
#  qEOM-Davidson calculation: 0.07 s
#  =====================================================================================
#
# r = 1.00
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -1.10251402     0.302      0.00
#       2     -1.11947739     0.266      0.00
#       3     -1.12354379     0.189      0.00
#       4     -1.12639890     0.118      0.00
#       5     -1.12677835     0.042      0.00
#       6     -1.12677835*    0.000      0.00
#  ------------------------------------------------
#  SCF energy                   = -1.09480796
#  ADAPT-VQE correlation energy = -0.03197039
#  ADAPT-VQE energy             = -1.12677835
#
#  ADAPT-VQE calculation: 15.12 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|01100000> + 0.70711|10010000>
#  |b2> =  + 1.00000|00110000>
#      1      2      0.2300     -0.6275475923     -0.2693210798
#      2      4      0.0748     -0.6377008691     -0.2989461639
#      3      6      0.0292     -0.6384303766     -0.3031469853
#      4      8      0.0047     -0.6384648959     -0.3056067197
#      5      9      0.0000     -0.6384648959     -0.3056243925
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -0.638465   13.287656   0.00  - 0.70460|01100000> + 0.70460|10010000>
#      2   -0.305624   22.344687   0.00  + 0.13540|00010010> - 0.13540|00100001> + 0.97295|00110000>
#
#  qEOM-Davidson calculation: 0.18 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|01100000> + 0.70711|10010000>
#  |b2> =  + 0.70711|01001000> + 0.70711|10000100>
#  |b3> =  + 0.70711|01000010> + 0.70711|10000001>
#      1      3      0.1309     -0.8625815347     -0.1674474554      0.0429971774
#      2      6      0.0000     -0.8666000526     -0.1757736311      0.0307862321
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -0.866600    7.079796   2.00  + 0.10904|01000010> - 0.69744|01100000> + 0.10904|10000001> - 0.69744|10010000>
#      2   -0.175774   25.878098   2.00  + 0.70222|01001000> + 0.70222|10000100>
#      3    0.030786   31.498866   2.00  - 0.10595|00011000> - 0.10595|00100100> - 0.68644|01000010> - 0.11296|01100000> - 0.68644|10000001> - 0.11296|10010000>
#
#  qEOM-Davidson calculation: 0.07 s
#  =====================================================================================
#
# r = 1.10
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -1.09382688     0.298      0.00
#       2     -1.10522546     0.257      0.00
#       3     -1.10853118     0.170      0.00
#       4     -1.11068589     0.110      0.00
#       5     -1.11126988     0.052      0.00
#       6     -1.11126988*    0.000      0.00
#  ------------------------------------------------
#  SCF energy                   = -1.07568569
#  ADAPT-VQE correlation energy = -0.03558419
#  ADAPT-VQE energy             = -1.11126988
#
#  ADAPT-VQE calculation: 15.13 s
#  ================================================
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|01100000> + 0.70711|10010000>
#  |b2> =  + 1.00000|00110000>
#      1      2      0.2281     -0.6385439318     -0.3401306468
#      2      4      0.0775     -0.6483042048     -0.3685008422
#      3      6      0.0345     -0.6485107630     -0.3740699238
#      4      8      0.0066     -0.6485150347     -0.3763384043
#      5      9      0.0000     -0.6485150347     -0.3763716866
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -0.648515   12.592172   0.00  - 0.70522|01100000> + 0.70522|10010000>
#      2   -0.376372   19.997553   0.00  + 0.13198|00010010> - 0.13198|00100001> - 0.97302|00110000>
#
#  qEOM-Davidson calculation: 0.18 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|01100000> + 0.70711|10010000>
#  |b2> =  + 0.70711|01001000> + 0.70711|10000100>
#  |b3> =  + 0.70711|01000010> + 0.70711|10000001>
#      1      3      0.1285     -0.8905527645     -0.1145153254      0.0133415164
#      2      6      0.0000     -0.8937520051     -0.1261520178     -0.0007845279
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -0.893752    5.918950   2.00  - 0.10656|01000010> - 0.69808|01100000> - 0.10656|10000001> - 0.69808|10010000>
#      2   -0.126152   26.806362   2.00  - 0.10980|00010010> - 0.10980|00100001> - 0.69853|01001000> - 0.69853|10000100>
#      3   -0.000785   30.217777   2.00  + 0.12376|00011000> + 0.12376|00100100> + 0.68419|01000010> - 0.11057|01100000> + 0.68419|10000001> - 0.11057|10010000>
#
#  qEOM-Davidson calculation: 0.07 s
#  =====================================================================================
#
# r = 1.20
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -1.07896018     0.294      0.00
#       2     -1.09052993     0.245      0.00
#       3     -1.09315957     0.154      0.00
#       4     -1.09474966     0.105      0.00
#       5     -1.09559549     0.063      0.00
#       6     -1.09559549*    0.000      0.00
#  ------------------------------------------------
#  SCF energy                   = -1.05575928
#  ADAPT-VQE correlation energy = -0.03983621
#  ADAPT-VQE energy             = -1.09559549
#
#  ADAPT-VQE calculation: 15.27 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|01100000> + 0.70711|10010000>
#  |b2> =  + 1.00000|00110000>
#      1      2      0.2254     -0.6458636953     -0.4010980889
#      2      4      0.0805     -0.6562552163     -0.4261715852
#      3      6      0.0343     -0.6563051882     -0.4328322915
#      4      8      0.0074     -0.6563081711     -0.4344715807
#      5      9      0.0000     -0.6563081711     -0.4345114120
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -0.656308   11.953590   0.00  + 0.70528|01100000> - 0.70528|10010000>
#      2   -0.434511   17.988973   0.00  - 0.12060|00010010> + 0.12060|00100001> + 0.97518|00110000>
#
#  qEOM-Davidson calculation: 0.18 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|01100000> + 0.70711|10010000>
#  |b2> =  + 0.70711|01001000> + 0.70711|10000100>
#  |b3> =  + 0.70711|01000010> + 0.70711|10000001>
#      1      3      0.1279     -0.9128613605     -0.0665672501     -0.0028594374
#      2      6      0.0000     -0.9154969510     -0.0828030525     -0.0193350953
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -0.915497    4.900720   2.00  - 0.10268|01000010> - 0.69883|01100000> - 0.10268|10000001> - 0.69883|10010000>
#      2   -0.082803   27.559424   2.00  - 0.14482|00010010> - 0.14482|00100001> - 0.69212|01001000> - 0.69212|10000100>
#      3   -0.019335   29.286471   2.00  + 0.14163|00011000> + 0.14163|00100100> + 0.68169|01000010> - 0.10672|01100000> + 0.68169|10000001> - 0.10672|10010000>
#
#  qEOM-Davidson calculation: 0.07 s
#  =====================================================================================
#
# r = 1.30
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -1.06474310     0.292      0.00
#       2     -1.07622894     0.233      0.00
#       3     -1.07828255     0.141      0.00
#       4     -1.07943537     0.103      0.00
#       5     -1.08060691     0.074      0.00
#       6     -1.08060691*    0.000      0.00
#  ------------------------------------------------
#  SCF energy                   = -1.03582611
#  ADAPT-VQE correlation energy = -0.04478080
#  ADAPT-VQE energy             = -1.08060691
#
#  ADAPT-VQE calculation: 15.41 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|01100000> + 0.70711|10010000>
#  |b2> =  + 1.00000|00110000>
#      1      2      0.2278     -0.6502991551     -0.4506282077
#      2      4      0.0844     -0.6620353763     -0.4735067344
#      3      6      0.0307     -0.6622376763     -0.4809715280
#      4      8      0.0072     -0.6622400446     -0.4820096941
#      5      9      0.0000     -0.6622400446     -0.4820479309
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -0.662240   11.384316   0.00  - 0.70494|01100000> + 0.70494|10010000>
#      2   -0.482048   16.287583   0.00  + 0.10962|00010010> - 0.10962|00100001> - 0.97704|00110000>
#
#  qEOM-Davidson calculation: 0.18 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|01100000> + 0.70711|10010000>
#  |b2> =  + 0.70711|01001000> + 0.70711|10000100>
#  |b3> =  + 0.70711|01000010> + 0.70711|10000001>
#      1      3      0.1288     -0.9306875859     -0.0269900834     -0.0090329004
#      2      6      0.0000     -0.9329177766     -0.0492714011     -0.0284492635
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -0.932918    4.018817   2.00  - 0.69961|01100000> - 0.69961|10010000>
#      2   -0.049271   28.064005   2.00  + 0.18721|00010010> + 0.18721|00100001> + 0.68188|01001000> + 0.68188|10000100>
#      3   -0.028449   28.630603   2.00  + 0.16120|00011000> + 0.16120|00100100> + 0.67837|01000010> - 0.10206|01100000> + 0.67837|10000001> - 0.10206|10010000>
#
#  qEOM-Davidson calculation: 0.07 s
#  =====================================================================================
#
# r = 1.40
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -1.05160669     0.290      0.00
#       2     -1.06281026     0.223      0.00
#       3     -1.06438626     0.133      0.00
#       4     -1.06591819     0.104      0.00
#       5     -1.06677528     0.062      0.00
#       6     -1.06677528*    0.000      0.00
#  ------------------------------------------------
#  SCF energy                   = -1.01632567
#  ADAPT-VQE correlation energy = -0.05044961
#  ADAPT-VQE energy             = -1.06677528
#
#  ADAPT-VQE calculation: 15.18 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
# ...
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -0.966660    2.089052   2.00  - 0.70177|01100000> - 0.70177|10010000>
#      2   -0.022446   27.782374   2.00  - 0.24733|00010010> - 0.24733|00100001> + 0.65478|01001000> + 0.65478|10000100>
#      3   -0.009815   28.126077   2.00  + 0.30089|00011000> + 0.30089|00100100> - 0.63989|01000010> - 0.63989|10000001>
#
#  qEOM-Davidson calculation: 0.07 s
#  =====================================================================================
#
# r = 1.70
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -1.02038181     0.293      0.00
#       2     -1.02998470     0.203      0.00
#       3     -1.03284121     0.130      0.00
#       4     -1.03371920     0.076      0.00
#       5     -1.03404474     0.038      0.00
#       6     -1.03404474*    0.000      0.00
#  ------------------------------------------------
#  SCF energy                   = -0.96231014
#  ADAPT-VQE correlation energy = -0.07173461
#  ADAPT-VQE energy             = -1.03404474
#
#  ADAPT-VQE calculation: 14.37 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|01100000> + 0.70711|10010000>
#  |b2> =  + 1.00000|00110000>
#      1      2      0.2598     -0.6469984043     -0.5649062135
#      2      4      0.0990     -0.6673146419     -0.5856069121
#      3      6      0.0148     -0.6693204925     -0.5942126560
#      4      8      0.0000     -0.6694525959     -0.5942894819
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -0.669453    9.921035   0.00  - 0.70170|01100000> + 0.70170|10010000>
#      2   -0.594289   11.966323   0.00  - 0.98081|00110000> - 0.11080|01000010> + 0.11080|10000001>
#
#  qEOM-Davidson calculation: 0.15 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|01100000> + 0.70711|10010000>
#  |b2> =  + 0.70711|01001000> + 0.70711|10000100>
#  |b3> =  + 0.70711|01000010> + 0.70711|10000001>
#      1      3      0.1408     -0.9723833923      0.0278785597      0.0379541106
#      2      6      0.0000     -0.9735432162     -0.0157855464     -0.0101769523
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -0.973543    1.646327   2.00  - 0.70235|01100000> - 0.70235|10010000>
#      2   -0.015786   27.708182   2.00  - 0.28960|00010010> - 0.28960|00100001> + 0.63796|01001000> + 0.63796|10000100>
#      3   -0.010177   27.860799   2.00  + 0.31732|00011000> + 0.31732|00100100> - 0.63191|01000010> - 0.63191|10000001>
#
#  qEOM-Davidson calculation: 0.07 s
#  =====================================================================================
#
# r = 1.80
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -1.01277850     0.295      0.00
#       2     -1.02171729     0.200      0.00
#       3     -1.02522992     0.134      0.00
#       4     -1.02590313     0.066      0.00
#       5     -1.02613571     0.032      0.00
#       6     -1.02613571*    0.000      0.00
#  ------------------------------------------------
#  SCF energy                   = -0.94605220
#  ADAPT-VQE correlation energy = -0.08008351
#  ADAPT-VQE energy             = -1.02613571
#
#  ADAPT-VQE calculation: 14.32 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|01100000> + 0.70711|10010000>
#  |b2> =  + 1.00000|00110000>
#      1      2      0.2686     -0.6424274724     -0.5783913681
#      2      4      0.1025     -0.6650143701     -0.5994188027
#      3      6      0.0140     -0.6675797178     -0.6081330483
#      4      8      0.0000     -0.6677615490     -0.6081701067
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -0.667762    9.751836   0.00  - 0.70070|01100000> + 0.70070|10010000>
#      2   -0.608170   11.373398   0.00  - 0.98099|00110000> - 0.11473|01000010> + 0.11473|10000001>
#
#  qEOM-Davidson calculation: 0.15 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|01100000> + 0.70711|10010000>
#  |b2> =  + 0.70711|01001000> + 0.70711|10000100>
#  |b3> =  + 0.70711|01000010> + 0.70711|10000001>
#      1      3      0.1452     -0.9779612002      0.0377972443      0.0453821323
#      2      6      0.0000     -0.9789220042     -0.0135687666     -0.0098522979
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -0.978922    1.284748   2.00  - 0.70286|01100000> - 0.70286|10010000>
#      2   -0.013569   27.553288   2.00  + 0.32394|00011000> + 0.32394|00100100> - 0.62854|01000010> - 0.62854|10000001>
#      3   -0.009852   27.654418   2.00  - 0.33834|00010010> - 0.33834|00100001> + 0.61418|01001000> + 0.61418|10000100>
#
#  qEOM-Davidson calculation: 0.07 s
#  =====================================================================================
#
# r = 1.90
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -1.00646024     0.297      0.00
#       2     -1.01472636     0.198      0.00
#       3     -1.01892458     0.140      0.00
#       4     -1.01943899     0.057      0.00
#       5     -1.01960353     0.027      0.00
#       6     -1.01960353*    0.000      0.00
#  ------------------------------------------------
#  SCF energy                   = -0.93070722
#  ADAPT-VQE correlation energy = -0.08889630
#  ADAPT-VQE energy             = -1.01960353
#
#  ADAPT-VQE calculation: 14.38 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|01100000> + 0.70711|10010000>
#  |b2> =  + 1.00000|00110000>
#      1      2      0.2769     -0.6369027417     -0.5876944330
#      2      4      0.1060     -0.6616517906     -0.6091921414
#      3      6      0.0150     -0.6647877236     -0.6180103976
#      4      8      0.0013     -0.6650246924     -0.6180457355
#      5      9      0.0000     -0.6650246924     -0.6180468984
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -0.665025    9.648560   0.00  + 0.69969|01100000> - 0.69969|10010000>
#      2   -0.618047   10.926888   0.00  - 0.98097|00110000> - 0.11786|01001000> + 0.11786|10000100>
#
#  qEOM-Davidson calculation: 0.18 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|01100000> + 0.70711|10010000>
#  |b2> =  + 0.70711|01001000> + 0.70711|10000100>
#  |b3> =  + 0.70711|01000010> + 0.70711|10000001>
#      1      3      0.1498     -0.9823215217      0.0348529579      0.0636629393
#      2      6      0.0000     -0.9831010186     -0.0186060610     -0.0061025952
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -0.983101    0.993282   2.00  - 0.70330|01100000> - 0.70330|10010000>
#      2   -0.018606   27.238467   2.00  + 0.32447|00010010> + 0.32447|00100001> + 0.62827|01001000> + 0.62827|10000100>
#      3   -0.006103   27.578703   2.00  - 0.39015|00011000> - 0.39015|00100100> - 0.58328|01000010> - 0.58328|10000001>
#
#  qEOM-Davidson calculation: 0.07 s
#  =====================================================================================
#
# r = 2.00
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -1.00129770     0.301      0.00
#       2     -1.00891297     0.196      0.00
#       3     -1.01380174     0.145      0.00
#       4     -1.01419515     0.049      0.00
#       5     -1.01431027     0.022      0.00
#       6     -1.01431027*    0.000      0.00
#  ------------------------------------------------
#  SCF energy                   = -0.91627125
#  ADAPT-VQE correlation energy = -0.09803902
#  ADAPT-VQE energy             = -1.01431027
#
#  ADAPT-VQE calculation: 14.73 s
#  ================================================
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|01100000> + 0.70711|10010000>
#  |b2> =  + 1.00000|00110000>
#      1      2      0.2843     -0.6306787837     -0.5935639559
#      2      4      0.1092     -0.6574287565     -0.6156071764
#      3      6      0.0174     -0.6611284999     -0.6245245972
#      4      8      0.0000     -0.6614253949     -0.6245901829
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -0.661425    9.602465   0.00  - 0.69870|01100000> + 0.69870|10010000>
#      2   -0.624590   10.604800   0.00  + 0.98081|00110000> + 0.12105|01001000> - 0.12105|10000100>
#
#  qEOM-Davidson calculation: 0.15 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|01100000> + 0.70711|10010000>
#  |b2> =  + 0.70711|01001000> + 0.70711|10000100>
#  |b3> =  + 0.70711|01000010> + 0.70711|10000001>
#      1      3      0.1546     -0.9857112026      0.0306177764      0.0816439126
#      2      6      0.0000     -0.9863298945     -0.0243389287     -0.0052856280
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -0.986330    0.761383   2.00  - 0.70366|01100000> - 0.70366|10010000>
#      2   -0.024339   26.938431   2.00  - 0.32222|00010010> - 0.32222|00100001> - 0.62942|01001000> - 0.62942|10000100>
#      3   -0.005286   27.456897   2.00  - 0.43974|00011000> - 0.43974|00100100> - 0.54748|01000010> - 0.54748|10000001>
#
#  qEOM-Davidson calculation: 0.07 s
#  =====================================================================================

# %%
print("singlet")
print_result(bond_lengths,singlet)
# Out:
# singlet
# Total Energy
# 0.20   0.0651688811   0.8551218207   1.0891847630
# 0.30  -0.6605101759   0.0774023404   0.3600200869
# 0.40  -0.9506786523  -0.2612218701   0.0691421811
# 0.50  -1.0778638980  -0.4313412469  -0.0550981821
# 0.60  -1.1319534575  -0.5231360248  -0.1017376424
# 0.70  -1.1501568433  -0.5749665977  -0.1083760327
# 0.80  -1.1500278825  -0.6056249916  -0.1147564606
# 0.90  -1.1406024516  -0.6250360756  -0.2196340586
# 1.00  -1.1267783499  -0.6384648959  -0.3056243925
# 1.10  -1.1112698803  -0.6485150347  -0.3763716866
# 1.20  -1.0955954918  -0.6563081711  -0.4345114120
# 1.30  -1.0806069068  -0.6622400446  -0.4820479309
# 1.40  -1.0667752785  -0.6664310165  -0.5205733372
# 1.50  -1.0543474433  -0.6689522445  -0.5514019233
# 1.60  -1.0434318158  -0.6699092624  -0.5756511135
# 1.70  -1.0340447442  -0.6694525959  -0.5942894819
# 1.80  -1.0261357143  -0.6677615490  -0.6081701067
# 1.90  -1.0196035253  -0.6650246924  -0.6180468984
# 2.00  -1.0143102688  -0.6614253949  -0.6245901829
#
# Excitation Energy
# 0.20  21.4956658353  27.8648285299
# 0.30  20.0795769847  27.7699802148
# 0.40  18.7610322754  27.7506757006
# 0.50  17.5927377024  27.8308098556
# 0.60  16.5667287662  28.0335369230
# 0.70  15.6516884646  28.3482357697
# 0.80  14.8139237614  28.1711066818
# 0.90  14.0292439959  25.0607698614
# 1.00  13.2876558874  22.3446868571
# 1.10  12.5921723007  19.9975532741
# 1.20  11.9535898623  17.9889734625
# 1.30  11.3843164772  16.2875825680
# 1.40  10.8938976525  14.8628783051
# 1.50  10.4871138427  13.6858137871
# 1.60  10.1640434357  12.7289325192
# 1.70   9.9210352821  11.9663231753
# 1.80   9.7518357287  11.3733978068
# 1.90   9.6485597073  10.9268877064
# 2.00   9.6024648396  10.6047997487

# %%
print("triplet")
print_result(bond_lengths,triplet)
# Out:
# triplet
# Total Energy
# 0.20   0.0651688811   0.8030234137   0.9101295704   2.0526329706
# 0.30  -0.6605101759   0.0119056320   0.1652016670   1.1995968039
# 0.40  -0.9506786523  -0.3444728631  -0.1357272694   0.7908583291
# 0.50  -1.0778638980  -0.5364842844  -0.2628944376   0.5621976777
# 0.60  -1.1319534575  -0.6534749317  -0.3054086879   0.4261057883
# 0.70  -1.1501568433  -0.7321053322  -0.3015536302   0.2738968018
# 0.80  -1.1500278825  -0.7890797943  -0.2711633104   0.1576054980
# 0.90  -1.1406024516  -0.8325088100  -0.2263638991   0.0808021211
# 1.00  -1.1267783499  -0.8666000526  -0.1757736311   0.0307862321
# 1.10  -1.1112698803  -0.8937520051  -0.1261520178  -0.0007845279
# 1.20  -1.0955954918  -0.9154969510  -0.0828030525  -0.0193350953
# 1.30  -1.0806069068  -0.9329177766  -0.0492714011  -0.0284492635
# 1.40  -1.0667752785  -0.9468362539  -0.0306656654  -0.0268418966
# 1.50  -1.0543474433  -0.9579056990  -0.0280327798  -0.0145034235
# 1.60  -1.0434318158  -0.9666604021  -0.0224460732  -0.0098151992
# 1.70  -1.0340447442  -0.9735432162  -0.0157855464  -0.0101769523
# 1.80  -1.0261357143  -0.9789220042  -0.0135687666  -0.0098522979
# 1.90  -1.0196035253  -0.9831010186  -0.0186060610  -0.0061025952
# 2.00  -1.0143102688  -0.9863298945  -0.0243389287  -0.0052856280
#
# Excitation Energy
# 0.20  20.0779991729  22.9924995661  54.0815304114
# 0.30  18.2973247942  22.4687129588  50.6159747638
# 0.40  16.4956624859  22.1759065877  47.3895280510
# 0.50  14.7316563816  22.1763985035  44.6282478531
# 0.60  13.0200344651  22.4913779976  42.3968558382
# 0.70  11.3757353557  23.0916174627  38.7503859437
# 0.80   9.8218755814  23.9150691265  35.5824363372
# 0.90   8.3836360817  24.8776419865  33.2360362606
# 1.00   7.0797960928  25.8780980711  31.4988655512
# 1.10   5.9189495024  26.8063618968  30.2177773539
# 1.20   4.9007198477  27.5594237872  29.2864709703
# 1.30   4.0188168579  28.0640051849  28.6306031305
# 1.40   3.2636997252  28.1939149710  28.2979647855
# 1.50   2.6243076076  27.9273814202  28.2955331278
# 1.60   2.0890518562  27.7823744256  28.1260772352
# 1.70   1.6463267155  27.7081815273  27.8607988021
# 1.80   1.2847475892  27.5532878623  27.6544178983
# 1.90   0.9932815580  27.2384668959  27.5787027612
# 2.00   0.7613830475  26.9384314506  27.4568970008

# %%
fci_energies = np.array([[0.0651688810, 0.8030234409, 0.8551218472, 0.9101296015, 1.0891847993, 2.0434667158],
                        [-0.6605101759, 0.0119056324, 0.0774023429, 0.1652016727, 0.3600191380, 1.1490607985],
                        [-0.9506786523,-0.3444728748,-0.2612218792,-0.1357272741, 0.0691421836, 0.6844123667],
                        [-1.0778638981,-0.5364843027,-0.4313412608,-0.2628944466,-0.0550981841, 0.3885683018],
                        [-1.1319534575,-0.6534749528,-0.5231360425,-0.3054086983,-0.1017376457, 0.1767450058],
                        [-1.1501568433,-0.7321053573,-0.5749666170,-0.3015536406,-0.1083760363, 0.0144206074],
                        [-1.1500278825,-0.7890798215,-0.6056250122,-0.2711633197,-0.1147564620,-0.0937890272],
                        [-1.1406024516,-0.8325088381,-0.6250360962,-0.2263639069,-0.2196340581,-0.0688732917],
                        [-1.1267783499,-0.8666000824,-0.6384649173,-0.1757736371,-0.3056243940,-0.0409334095],
                        [-1.1112698803,-0.8937520354,-0.6485150571,-0.1261520221,-0.3763716868,-0.0152712215],
                        [-1.0955954918,-0.9154969824,-0.6563081938,-0.0828030554,-0.4345114115,-0.0193350960],
                        [-1.0806069068,-0.9329178085,-0.6622400671,-0.0492714028,-0.4820479308,-0.0284492645],
                        [-1.0667752785,-0.9468362863,-0.6664310392,-0.0306656664,-0.5205733386,-0.0268418975],
                        [-1.0543474433,-0.9579057317,-0.6689522687,-0.0280327805,-0.5514019224,-0.0145034239],
                        [-1.0434318158,-0.9666604352,-0.6699092846,-0.0224460740,-0.5756511137,-0.0098151996],
                        [-1.0340447442,-0.9735432495,-0.6694526201,-0.0157855469,-0.5942900813,-0.0101769527],
                        [-1.0261357143,-0.9789220376,-0.6677615711,-0.0135687671,-0.6081704564,-0.0098522980],
                        [-1.0196035253,-0.9831010522,-0.6650247147,-0.0186060616,-0.6180468994,-0.0061025954],
                        [-1.0143102688,-0.9863299282,-0.6614254185,-0.0243389295,-0.6245901830,-0.0052856281]])

# %%
# Plot.
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(0)
plt.plot(bond_lengths, fci_energies[:,0], '--', label='GS', color='black')
plt.plot(bond_lengths, fci_energies[:,1], '--', label='T1', color='red')
plt.plot(bond_lengths, fci_energies[:,2], '--', label='S1', color='blue')
plt.plot(bond_lengths, fci_energies[:,3], '--', label='T2', color='green')
plt.plot(bond_lengths, fci_energies[:,4], '--', label='S2', color='orange')
# plt.plot(bond_lengths, fci_energies[:,5], '--', label='T3', color='brown')

plt.plot(bond_lengths, triplet[:,0], 'o', label='GS', color='black')
plt.plot(bond_lengths, triplet[:,1], 'o', label='T1', color='red')
plt.plot(bond_lengths, triplet[:,2], 'o', label='T2', color='green')
# plt.plot(bond_lengths, triplet[:,3], 'o', label='T3', color='brown')
plt.plot(bond_lengths, singlet[:,1], 'o', label='S1', color='blue')
plt.plot(bond_lengths, singlet[:,2], 'o', label='S2', color='orange')

plt.ylabel('Energy in Hartree')
plt.xlabel('Bond length in angstrom')
plt.legend()
plt.show()

# %%
# Plot.
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(0)
plt.plot(bond_lengths, abs(fci_energies[:,1]-triplet[:,1])*1000, 'o', label='T1', color='red')
plt.plot(bond_lengths, abs(fci_energies[:,2]-singlet[:,1])*1000, 'o', label='S1', color='blue')
plt.plot(bond_lengths, abs(fci_energies[:,3]-triplet[:,2])*1000, 'o', label='T2', color='green')
plt.plot(bond_lengths, abs(fci_energies[:,4]-singlet[:,2])*1000, 'o', label='S2', color='orange')
# plt.plot(bond_lengths, abs(fci_energies[:,5]-triplet[:,3])*1000, 'o', label='T3', color='brown')

plt.ylabel('Error in mHartree')
plt.xlabel('Bond length in angstrom')
plt.legend()
plt.show()
