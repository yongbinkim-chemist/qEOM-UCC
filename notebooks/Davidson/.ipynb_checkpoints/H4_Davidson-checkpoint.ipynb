# %%
import numpy as np
import openfermion
from openfermion.chem import MolecularData
from openfermionqchem import run_qchem
import qeom

# %%
def print_result(bond,energy):   
    string1,string2 = "Total Energy\n","Excitation Energy\n"
    
    for i in range(len(bond)):
        string1 += "{:4.2f}".format(bond[i])
        string2 += "{:4.2f}".format(bond[i])

        for j in range(len(energy[i])):
            string1 += "{:15.10f}".format(energy[i][j])
        string1 += '\n'

        for j in range(1,len(energy[i])):
            string2 += "{:15.10f}".format((energy[i][j] - energy[i][0]) * 27.211324570273)
        string2 += '\n'
        
    print(string1+'\n'+string2)

# %% [markdown]
# ## H4/STO-3G

# %%
# Set molecule parameters.
# We do not run calculations through OpenFermion directly.
basis        = 'sto-3g'
multiplicity = 1

# Generate molecule at different bond lengths.
bond_length_interval = 0.05
n_points = 14
singlet  = []
triplet  = []
bond_lengths = []

for point in range(n_points):
    bond_length    = 1.75 + point * bond_length_interval
    geometry       = [('H', (0., 0., 0.)), ('H', (0., 0., bond_length))]
    molecule       = MolecularData(geometry, basis, multiplicity)
    directory      = "/Users/yongbinkim/Desktop/venv/publish/qeom-davidson/OpenFermion-QChem/examples/"
    system         = 'H4/eom-ccsd/sto-3g/'+str(round(bond_length,3)).ljust(4,"0")+'/'
    molecule       = run_qchem(molecule,file_directory=directory+system,output_name='test_qis')

    print("r = {:4.2f}".format(bond_length))
    bond_lengths.append(bond_length)
    
    # ground state
    gs = qeom.Adapt_VQE(molecule)
    gs.run()
    
    qeom_davidson = qeom.Davidson(gs=gs)
    
    # singlet
    user_guess = [[[0,1,2,5],[0,1,3,4]],[[0,1,2,7],[0,1,3,6]],[[0,1,4,5]]]
    qeom_davidson.run(nroot=3,user_guess=user_guess,spin='singlet')
    singlet.append(qeom_davidson.energy)

    # triplet
    qeom_davidson.run(nroot=2,spin='triplet')
    triplet.append(qeom_davidson.energy)
    
singlet      = np.array(singlet)
triplet      = np.array(triplet)   
bond_lengths = np.array(bond_lengths)
# Out:
# r = 1.75
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -1.82952518     0.479      0.00
#       2     -1.87614865     0.443      0.00
#       3     -1.92577017     0.336      0.00
#       4     -1.94379515     0.151      0.00
#       5     -1.96292785     0.179      0.00
#       6     -1.96520436     0.036      0.00
#       7     -1.96526312     0.002     -0.00
#       8     -1.96526312*    0.000     -0.00
#  ------------------------------------------------
#  SCF energy                   = -1.76954677
#  ADAPT-VQE correlation energy = -0.19571635
#  ADAPT-VQE energy             = -1.96526312
#
#  ADAPT-VQE calculation: 33.64 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  - 0.70711|11010010> + 0.70711|11100001>
#  |b3> =  + 1.00000|11001100>
#      1      3      0.2729     -1.5859952042     -1.5207989031     -1.3973527970
#      2      6      0.2774     -1.6955713859     -1.5871401292     -1.4491152376
#      3      7      0.0508     -1.8043588492     -1.5871401292     -1.4491152376
#      4      8      0.0069     -1.8080580728     -1.5871401292     -1.4491152376
#      5      9      0.0000     -1.8081051439     -1.5871401292     -1.4491152376
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.808105    4.276477   0.00  - 0.12218|00110011> + 0.41912|00111100> - 0.25647|01011010> + 0.18267|01100110> + 0.18267|10011001> - 0.25647|10100101> + 0.44566|11000011> - 0.63374|11001100>
#      2   -1.587140   10.289228   0.00  + 0.70576|11011000> - 0.70576|11100100>
#      3   -1.449115   14.045068   0.00  + 0.53564|01111000> - 0.53564|10110100> + 0.46161|11010010> - 0.46161|11100001>
#
#  qEOM-Davidson calculation: 0.31 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  + 0.70711|01111000> + 0.70711|10110100>
#      1      2      0.2808     -1.7997906077     -1.6415581437
#      2      4      0.0000     -1.9021325400     -1.8434999872
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.902133    1.717867   2.00  + 0.31997|01110010> + 0.31997|10110001> - 0.63057|11011000> - 0.63057|11100100>
#      2   -1.843500    3.313336   2.00  + 0.49176|01111000> + 0.49176|10110100> - 0.50811|11010010> - 0.50811|11100001>
#
#  qEOM-Davidson calculation: 0.06 s
#  =====================================================================================
#
# r = 1.80
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -1.83585836     0.477      0.00
#       2     -1.88221628     0.444      0.00
#       3     -1.93165707     0.337      0.00
#       4     -1.94849654     0.153      0.00
#       5     -1.96725351     0.176      0.00
#       6     -1.96888992     0.030      0.00
#       7     -1.96891484     0.001      0.00
#       8     -1.96891484*    0.000      0.00
#  ------------------------------------------------
#  SCF energy                   = -1.77674732
#  ADAPT-VQE correlation energy = -0.19216752
#  ADAPT-VQE energy             = -1.96891484
#
#  ADAPT-VQE calculation: 33.98 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  - 0.70711|11010010> + 0.70711|11100001>
#  |b3> =  + 1.00000|11001100>
#      1      3      0.2849     -1.5785960517     -1.5047252966     -1.4033617093
#      2      6      0.2799     -1.6783826441     -1.5796812223     -1.4521165865
#      3      7      0.0552     -1.8019144176     -1.5796812223     -1.4521165865
#      4      8      0.0073     -1.8064254193     -1.5796812223     -1.4521165865
#      5      9      0.0000     -1.8064784829     -1.5796812223     -1.4521165865
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.806478    4.420108   0.00  + 0.14558|00110011> - 0.42534|00111100> + 0.25878|01011010> - 0.17126|01100110> - 0.17126|10011001> + 0.25878|10100101> - 0.45121|11000011> + 0.62160|11001100>
#      2   -1.579681   10.591562   0.00  + 0.70574|11011000> - 0.70574|11100100>
#      3   -1.452117   14.062765   0.00  + 0.53501|01111000> - 0.53501|10110100> + 0.46235|11010010> - 0.46235|11100001>
#
#  qEOM-Davidson calculation: 0.30 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  + 0.70711|11010010> + 0.70711|11100001>
#      1      2      0.2850     -1.7919251493     -1.6596153251
#      2      4      0.0000     -1.9010665740     -1.8518607661
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.901067    1.846241   2.00  + 0.33318|01110010> + 0.33318|10110001> - 0.62369|11011000> - 0.62369|11100100>
#      2   -1.851861    3.185196   2.00  + 0.49175|01111000> + 0.49175|10110100> - 0.50812|11010010> - 0.50812|11100001>
#
#  qEOM-Davidson calculation: 0.06 s
#  =====================================================================================
#
# r = 1.85
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -1.84130345     0.475      0.00
#       2     -1.88739947     0.445      0.00
#       3     -1.93670728     0.339      0.00
#       4     -1.95260564     0.154      0.00
#       5     -1.97113325     0.174      0.00
#       6     -1.97232818     0.026     -0.00
#       7     -1.97232818*    0.001     -0.00
#  ------------------------------------------------
#  SCF energy                   = -1.78300199
#  ADAPT-VQE correlation energy = -0.18932618
#  ADAPT-VQE energy             = -1.97232818
#
#  ADAPT-VQE calculation: 23.25 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  - 0.70711|11010010> + 0.70711|11100001>
#  |b3> =  + 1.00000|11001100>
#      1      3      0.3071     -1.5704422480     -1.4846723628     -1.4081285612
#      2      6      0.2753     -1.6608850665     -1.5709049775     -1.4536919117
#      3      7      0.0590     -1.7982232715     -1.5709049775     -1.4536919117
#      4      8      0.0057     -1.8036439156     -1.5709049775     -1.4536919117
#      5      9      0.0000     -1.8036770125     -1.5709049775     -1.4536919117
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.803677    4.589222   0.00  - 0.16155|00110011> + 0.43016|00111100> - 0.25830|01011010> + 0.15599|01100110> + 0.10231|01101001> + 0.10231|10010110> + 0.15599|10011001> - 0.25830|10100101> + 0.45527|11000011> - 0.61527|11001100>
#      2   -1.570905   10.923257   0.00  + 0.70648|11011000> - 0.70648|11100100>
#      3   -1.453692   14.112780   0.00  - 0.53452|01111000> + 0.53452|10110100> - 0.46292|11010010> + 0.46292|11100001>
#
#  qEOM-Davidson calculation: 0.30 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  + 0.70711|11010010> + 0.70711|11100001>
#      1      2      0.2898     -1.7810764002     -1.6635343246
#      2      4      0.0000     -1.8994418039     -1.8585898197
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.899442    1.983335   2.00  + 0.34948|01110010> + 0.34948|10110001> - 0.61471|11011000> - 0.61471|11100100>
#      2   -1.858590    3.094971   2.00  - 0.49178|01111000> - 0.49178|10110100> + 0.50809|11010010> + 0.50809|11100001>
#
#  qEOM-Davidson calculation: 0.06 s
#  =====================================================================================
#
# r = 1.90
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -1.84597414     0.473      0.00
#       2     -1.89181306     0.446      0.00
#       3     -1.94103129     0.340      0.00
#       4     -1.95616717     0.156      0.00
#       5     -1.97457552     0.172      0.00
#       6     -1.97546176     0.022     -0.00
#       7     -1.97546176*    0.000     -0.00
#  ------------------------------------------------
#  SCF energy                   = -1.78842885
#  ADAPT-VQE correlation energy = -0.18703291
#  ADAPT-VQE energy             = -1.97546176
#
#  ADAPT-VQE calculation: 22.36 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  - 0.70711|11010010> + 0.70711|11100001>
#  |b3> =  + 1.00000|11001100>
#      1      3      0.3144     -1.5620900659     -1.4665475532     -1.4119680341
#      2      6      0.2788     -1.6475549036     -1.5625966215     -1.4541919075
#      3      7      0.0625     -1.7950669660     -1.5625966215     -1.4541919075
#      4      8      0.0083     -1.8011967556     -1.5625966215     -1.4541919075
#      5      9      0.0000     -1.8012685770     -1.5625966215     -1.4541919075
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.801269    4.740027   0.00  + 0.18115|00110011> - 0.43413|00111100> + 0.26223|01011010> - 0.15252|01100110> - 0.10971|01101001> - 0.10971|10010110> - 0.15252|10011001> + 0.26223|10100101> - 0.45865|11000011> + 0.60019|11001100>
#      2   -1.562597   11.234607   0.00  + 0.70637|11011000> - 0.70637|11100100>
#      3   -1.454192   14.184443   0.00  - 0.53398|01111000> + 0.53398|10110100> - 0.46353|11010010> + 0.46353|11100001>
#
#  qEOM-Davidson calculation: 0.35 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  + 0.70711|11010010> + 0.70711|11100001>
#      1      2      0.2922     -1.7745846446     -1.6663141857
#      2      4      0.0000     -1.8984047655     -1.8635290571
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.898405    2.096823   2.00  + 0.35980|01110010> + 0.35980|10110001> - 0.60873|11011000> - 0.60873|11100100>
#      2   -1.863529    3.045837   2.00  - 0.49176|01111000> - 0.49176|10110100> + 0.50811|11010010> + 0.50811|11100001>
#
#  qEOM-Davidson calculation: 0.06 s
#  =====================================================================================
#
# r = 1.95
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -1.84997035     0.471      0.00
#       2     -1.89555788     0.447      0.00
#       3     -1.94472578     0.342      0.00
#       4     -1.95923341     0.157      0.00
#       5     -1.97760568     0.171      0.00
#       6     -1.97827282     0.020      0.00
#       7     -1.97827282*    0.000      0.00
#  ------------------------------------------------
#  SCF energy                   = -1.79313192
#  ADAPT-VQE correlation energy = -0.18514091
#  ADAPT-VQE energy             = -1.97827282
#
#  ADAPT-VQE calculation: 21.68 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  - 0.70711|11010010> + 0.70711|11100001>
#  |b3> =  + 1.00000|11001100>
#      1      3      0.3212     -1.5538465840     -1.4486118955     -1.4150426017
#      2      6      0.2823     -1.6344522592     -1.5543566374     -1.4539873006
#      3      7      0.0659     -1.7918778739     -1.5543566374     -1.4539873006
#      4      8      0.0109     -1.7987176830     -1.5543566374     -1.4539873006
#      5      9      0.0000     -1.7988445485     -1.5543566374     -1.4539873006
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.798845    4.882481   0.00  + 0.19890|00110011> - 0.43760|00111100> + 0.26579|01011010> - 0.15001|01100110> - 0.11578|01101001> - 0.11578|10010110> - 0.15001|10011001> + 0.26579|10100101> - 0.46147|11000011> + 0.58556|11001100>
#      2   -1.554357   11.535321   0.00  + 0.70630|11011000> - 0.70630|11100100>
#      3   -1.453987   14.266504   0.00  + 0.53351|01111000> - 0.53351|10110100> + 0.46407|11010010> - 0.46407|11100001>
#
#  qEOM-Davidson calculation: 0.30 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  + 0.70711|11010010> + 0.70711|11100001>
#      1      2      0.2947     -1.7679512441     -1.6683008109
#      2      4      0.0000     -1.8973237460     -1.8676000951
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.897324    2.202732   2.00  + 0.36983|01110010> + 0.36983|10110001> - 0.60268|11011000> - 0.60268|11100100>
#      2   -1.867600    3.011552   2.00  + 0.49178|01111000> + 0.49178|10110100> - 0.50809|11010010> - 0.50809|11100001>
#
#  qEOM-Davidson calculation: 0.06 s
#  =====================================================================================
#
# r = 2.00
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -1.85337994     0.470      0.00
#       2     -1.89872250     0.448      0.00
#       3     -1.94787535     0.343      0.00
#       4     -1.96185797     0.159      0.00
#       5     -1.98025718     0.171      0.00
#       6     -1.98076649     0.017      0.00
#       7     -1.98076649*    0.000      0.00
#  ------------------------------------------------
#  SCF energy                   = -1.79720283
#  ADAPT-VQE correlation energy = -0.18356365
#  ADAPT-VQE energy             = -1.98076649
#
#  ADAPT-VQE calculation: 21.82 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  - 0.70711|11010010> + 0.70711|11100001>
#  |b3> =  + 1.00000|11001100>
#      1      3      0.3275     -1.5457780942     -1.4310599049     -1.4174789853
#      2      6      0.2857     -1.6216781875     -1.5462604805     -1.4532409710
#      3      7      0.0693     -1.7887898732     -1.5462604805     -1.4532409710
#      4      8      0.0134     -1.7963419778     -1.5462604805     -1.4532409710
#      5      9      0.0000     -1.7965381912     -1.5462604805     -1.4532409710
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.796538    5.013096   0.00  - 0.21507|00110011> + 0.44069|00111100> - 0.26898|01011010> + 0.14821|01100110> + 0.12077|01101001> + 0.12077|10010110> + 0.14821|10011001> - 0.26898|10100101> + 0.46383|11000011> - 0.57149|11001100>
#      2   -1.546260   11.823484   0.00  + 0.70628|11011000> - 0.70628|11100100>
#      3   -1.453241   14.354668   0.00  - 0.53312|01111000> + 0.53312|10110100> - 0.46452|11010010> + 0.46452|11100001>
#
#  qEOM-Davidson calculation: 0.30 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  + 0.70711|11010010> + 0.70711|11100001>
#      1      2      0.2971     -1.7612769475     -1.6696411597
#      2      4      0.0000     -1.8962642089     -1.8709855237
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.896264    2.299419   2.00  + 0.37950|01110010> + 0.37950|10110001> - 0.59664|11011000> - 0.59664|11100100>
#      2   -1.870986    2.987285   2.00  + 0.49185|01111000> + 0.49185|10110100> - 0.50802|11010010> - 0.50802|11100001>
#
#  qEOM-Davidson calculation: 0.06 s
#  =====================================================================================
#
# r = 2.05
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -1.85627992     0.469      0.00
#       2     -1.90138448     0.449      0.00
#       3     -1.95055382     0.345      0.00
#       4     -1.96409241     0.160      0.00
#       5     -1.98256637     0.170      0.00
#       6     -1.98296032     0.015     -0.00
#       7     -1.98296032*    0.000     -0.00
#  ------------------------------------------------
#  SCF energy                   = -1.80072223
#  ADAPT-VQE correlation energy = -0.18223809
#  ADAPT-VQE energy             = -1.98296032
#
#  ADAPT-VQE calculation: 21.75 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  - 0.70711|11010010> + 0.70711|11100001>
#  |b3> =  + 1.00000|11001100>
#      1      3      0.3333     -1.5379298344     -1.4193769599     -1.4140222327
#      2      6      0.2892     -1.6093037167     -1.5383618763     -1.4520702157
#      3      7      0.0727     -1.7858746058     -1.5383618763     -1.4520702157
#      4      8      0.0156     -1.7941435203     -1.5383618763     -1.4520702157
#      5      9      0.0000     -1.7944202097     -1.5383618763     -1.4520702157
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.794420    5.130426   0.00  + 0.22988|00110011> - 0.44346|00111100> + 0.27179|01011010> - 0.14693|01100110> - 0.12486|01101001> - 0.12486|10010110> - 0.14693|10011001> + 0.27179|10100101> - 0.46579|11000011> + 0.55807|11001100>
#      2   -1.538362   12.098112   0.00  + 0.70631|11011000> - 0.70631|11100100>
#      3   -1.452070   14.446223   0.00  + 0.53283|01111000> - 0.53283|10110100> + 0.46486|11010010> - 0.46486|11100001>
#
#  qEOM-Davidson calculation: 0.30 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  + 0.70711|11010010> + 0.70711|11100001>
#      1      2      0.2996     -1.7546409444     -1.6704497654
#      2      4      0.0000     -1.8952661131     -1.8738177349
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.895266    2.386275   2.00  + 0.38874|01110010> + 0.38874|10110001> - 0.59066|11011000> - 0.59066|11100100>
#      2   -1.873818    2.969914   2.00  - 0.49196|01111000> - 0.49196|10110100> + 0.50791|11010010> + 0.50791|11100001>
#
#  qEOM-Davidson calculation: 0.06 s
#  =====================================================================================
#
# r = 2.10
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -1.85873791     0.468      0.00
#       2     -1.90361186     0.450      0.00
#       3     -1.95282568     0.346      0.00
#       4     -1.96598483     0.162      0.00
#       5     -1.98456967     0.170      0.00
#       6     -1.98487817     0.013      0.00
#       7     -1.98487817*    0.000      0.00
#  ------------------------------------------------
#  SCF energy                   = -1.80376100
#  ADAPT-VQE correlation energy = -0.18111716
#  ADAPT-VQE energy             = -1.98487817
#
#  ADAPT-VQE calculation: 21.80 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  - 0.70711|11010010> + 0.70711|11100001>
#  |b3> =  + 1.00000|11001100>
#      1      3      0.3388     -1.5303326395     -1.4208176353     -1.3975842790
#      2      6      0.2925     -1.5973760815     -1.5306991206     -1.4505628987
#      3      7      0.0761     -1.7831634269     -1.5306991206     -1.4505628987
#      4      8      0.0176     -1.7921555688     -1.5306991206     -1.4505628987
#      5      9      0.0000     -1.7925203934     -1.5306991206     -1.4505628987
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.792520    5.234310   0.00  - 0.24348|00110011> + 0.44595|00111100> - 0.27427|01011010> + 0.14603|01100110> + 0.12824|01101001> + 0.12824|10010110> + 0.14603|10011001> - 0.27427|10100101> + 0.46739|11000011> - 0.54536|11001100>
#      2   -1.530699   12.358813   0.00  + 0.70637|11011000> - 0.70637|11100100>
#      3   -1.450563   14.539426   0.00  + 0.53266|01111000> - 0.53266|10110100> + 0.46505|11010010> - 0.46505|11100001>
#
#  qEOM-Davidson calculation: 0.32 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  + 0.70711|11010010> + 0.70711|11100001>
#      1      2      0.3020     -1.7481037609     -1.6708184734
#      2      4      0.0000     -1.8943514116     -1.8761965741
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.894351    2.463353   2.00  + 0.39751|01110010> + 0.39751|10110001> - 0.58479|11011000> - 0.58479|11100100>
#      2   -1.876197    2.957370   2.00  + 0.49211|01111000> + 0.49211|10110100> - 0.50777|11010010> - 0.50777|11100001>
#
#  qEOM-Davidson calculation: 0.06 s
#  =====================================================================================
#
# r = 2.15
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -1.86081308     0.467      0.00
#       2     -1.90546409     0.451      0.00
#       3     -1.95474711     0.348      0.00
#       4     -1.96757908     0.163      0.00
#       5     -1.98630188     0.170      0.00
#       6     -1.98654626     0.012      0.00
#       7     -1.98654626*    0.000      0.00
#  ------------------------------------------------
#  SCF energy                   = -1.80638141
#  ADAPT-VQE correlation energy = -0.18016484
#  ADAPT-VQE energy             = -1.98654626
#
#  ADAPT-VQE calculation: 21.71 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  - 0.70711|11010010> + 0.70711|11100001>
#  |b3> =  + 1.00000|11001100>
#      1      3      0.3440     -1.5230067395     -1.4218684670     -1.3817984010
#      2      6      0.2958     -1.5859242257     -1.5232990530     -1.4487870711
#      3      7      0.0794     -1.7806639786     -1.5232990530     -1.4487870711
#      4      8      0.0195     -1.7903867747     -1.5232990530     -1.4487870711
#      5      9      0.0000     -1.7908441951     -1.5232990530     -1.4487870711
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.790844    5.325312   0.00  - 0.25601|00110011> + 0.44819|00111100> - 0.27642|01011010> + 0.14540|01100110> + 0.13102|01101001> + 0.13102|10010110> + 0.14540|10011001> - 0.27642|10100101> + 0.46867|11000011> - 0.53339|11001100>
#      2   -1.523299   12.605570   0.00  + 0.70647|11011000> - 0.70647|11100100>
#      3   -1.448787   14.633140   0.00  - 0.53265|01111000> + 0.53265|10110100> - 0.46506|11010010> + 0.46506|11100001>
#
#  qEOM-Davidson calculation: 0.30 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  + 0.70711|11010010> + 0.70711|11100001>
#      1      2      0.3044     -1.7417103926     -1.6708223868
#      2      4      0.0000     -1.8935295766     -1.8781995430
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.893530    2.531107   2.00  + 0.40578|01110010> + 0.40578|10110001> - 0.57909|11011000> - 0.57909|11100100>
#      2   -1.878200    2.948258   2.00  + 0.49229|01111000> + 0.49229|10110100> - 0.50759|11010010> - 0.50759|11100001>
#
#  qEOM-Davidson calculation: 0.06 s
#  =====================================================================================
#
# r = 2.20
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -1.86255726     0.466      0.00
#       2     -1.90699324     0.452      0.00
#       3     -1.95636703     0.349      0.00
#       4     -1.96891466     0.164      0.00
#       5     -1.98779540     0.170      0.00
#       6     -1.98799111     0.011      0.00
#       7     -1.98799111*    0.000      0.00
#  ------------------------------------------------
#  SCF energy                   = -1.80863808
#  ADAPT-VQE correlation energy = -0.17935302
#  ADAPT-VQE energy             = -1.98799111
#
#  ADAPT-VQE calculation: 21.27 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  - 0.70711|11010010> + 0.70711|11100001>
#  |b3> =  + 1.00000|11001100>
#      1      3      0.3490     -1.5159648392     -1.4225861723     -1.3666949749
#      2      6      0.2990     -1.5749663430     -1.5161804821     -1.4467967336
#      3      7      0.0826     -1.7783712107     -1.5161804821     -1.4467967336
#      4      8      0.0211     -1.7888315965     -1.5161804821     -1.4467967336
#      5      9      0.0000     -1.7893833916     -1.5161804821     -1.4467967336
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.789383    5.404379   0.00  - 0.26755|00110011> + 0.45020|00111100> - 0.27828|01011010> + 0.14496|01100110> + 0.13332|01101001> + 0.13332|10010110> + 0.14496|10011001> - 0.27828|10100101> + 0.46968|11000011> - 0.52219|11001100>
#      2   -1.516180   12.838592   0.00  + 0.70660|11011000> - 0.70660|11100100>
#      3   -1.446797   14.726616   0.00  + 0.53283|01111000> - 0.53283|10110100> + 0.46485|11010010> - 0.46485|11100001>
#
#  qEOM-Davidson calculation: 0.30 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  + 0.70711|11010010> + 0.70711|11100001>
#      1      2      0.3068     -1.7354939264     -1.6705240525
#      2      4      0.0000     -1.8928025776     -1.8798885003
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.892803    2.590206   2.00  + 0.41354|01110010> + 0.41354|10110001> - 0.57358|11011000> - 0.57358|11100100>
#      2   -1.879889    2.941615   2.00  - 0.49251|01111000> - 0.49251|10110100> + 0.50738|11010010> + 0.50738|11100001>
#
#  qEOM-Davidson calculation: 0.06 s
#  =====================================================================================
#
# r = 2.25
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -1.86401571     0.465      0.00
#       2     -1.90824474     0.453      0.00
#       3     -1.95772799     0.351      0.00
#       4     -1.97002679     0.165      0.00
#       5     -1.98907982     0.171      0.00
#       6     -1.98923817     0.010      0.00
#       7     -1.98923817*    0.000      0.00
#  ------------------------------------------------
#  SCF energy                   = -1.81057888
#  ADAPT-VQE correlation energy = -0.17865929
#  ADAPT-VQE energy             = -1.98923817
#
#  ADAPT-VQE calculation: 21.29 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  - 0.70711|11010010> + 0.70711|11100001>
#  |b3> =  + 1.00000|11001100>
#      1      3      0.3537     -1.5092129955     -1.4230208893     -1.3522813595
#      2      6      0.3021     -1.5645006445     -1.5093552601     -1.4446372171
#      3      7      0.0858     -1.7762698737     -1.5093552601     -1.4446372171
#      4      8      0.0225     -1.7874743601     -1.5093552601     -1.4446372171
#      5      9      0.0000     -1.7881204190     -1.5093552601     -1.4446372171
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.788120    5.472680   0.00  + 0.27819|00110011> - 0.45201|00111100> + 0.27988|01011010> - 0.14466|01100110> - 0.13522|01101001> - 0.13522|10010110> - 0.14466|10011001> + 0.27988|10100101> - 0.47045|11000011> + 0.51174|11001100>
#      2   -1.509355   13.058250   0.00  + 0.70674|11011000> - 0.70674|11100100>
#      3   -1.444637   14.819313   0.00  + 0.53326|01111000> - 0.53326|10110100> + 0.46437|11010010> - 0.46437|11100001>
#
#  qEOM-Davidson calculation: 0.29 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  + 0.70711|11010010> + 0.70711|11100001>
#      1      2      0.3092     -1.7294765324     -1.6699759889
#      2      4      0.0000     -1.8921656273     -1.8813135566
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.892166    2.641473   2.00  + 0.42077|01110010> + 0.42077|10110001> - 0.56829|11011000> - 0.56829|11100100>
#      2   -1.881314    2.936772   2.00  + 0.49275|01111000> + 0.49275|10110100> - 0.50714|11010010> - 0.50714|11100001>
#
#  qEOM-Davidson calculation: 0.06 s
#  =====================================================================================
#
# r = 2.30
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -1.86522797     0.464      0.00
#       2     -1.90925821     0.454      0.00
#       3     -1.95886693     0.352      0.00
#       4     -1.97094662     0.167      0.00
#       5     -1.99018185     0.171      0.00
#       6     -1.99031122     0.009      0.00
#       7     -1.99031122*    0.000      0.00
#  ------------------------------------------------
#  SCF energy                   = -1.81224571
#  ADAPT-VQE correlation energy = -0.17806551
#  ADAPT-VQE energy             = -1.99031122
#
#  ADAPT-VQE calculation: 21.38 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  - 0.70711|11010010> + 0.70711|11100001>
#  |b3> =  + 1.00000|11001100>
#      1      3      0.3582     -1.5027535610     -1.4232143007     -1.3385587795
#      2      6      0.3051     -1.5545282719     -1.5028316873     -1.4423449348
#      3      7      0.0889     -1.7743448016     -1.5028316873     -1.4423449348
#      4      8      0.0238     -1.7862974906     -1.5028316873     -1.4423449348
#      5      9      0.0000     -1.7870362660     -1.5028316873     -1.4423449348
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.787036    5.531381   0.00  - 0.28800|00110011> + 0.45364|00111100> - 0.28126|01011010> + 0.14446|01100110> + 0.13680|01101001> + 0.13680|10010110> + 0.14446|10011001> - 0.28126|10100101> + 0.47101|11000011> - 0.50203|11001100>
#      2   -1.502832   13.264964   0.00  + 0.70689|11011000> - 0.70689|11100100>
#      3   -1.442345   14.910888   0.00  - 0.53399|01111000> + 0.53399|10110100> - 0.46353|11010010> + 0.46353|11100001>
#
#  qEOM-Davidson calculation: 0.29 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  + 0.70711|11010010> + 0.70711|11100001>
#      1      2      0.3115     -1.7236740682     -1.6692228254
#      2      4      0.0000     -1.8916129616     -1.8825161501
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.891613    2.685710   2.00  + 0.42750|01110010> + 0.42750|10110001> - 0.56325|11011000> - 0.56325|11100100>
#      2   -1.882516    2.933247   2.00  + 0.49302|01111000> + 0.49302|10110100> - 0.50688|11010010> - 0.50688|11100001>
#
#  qEOM-Davidson calculation: 0.06 s
#  =====================================================================================
#
# r = 2.35
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -1.86622843     0.464      0.00
#       2     -1.91006813     0.455      0.00
#       3     -1.95981582     0.354      0.00
#       4     -1.97170152     0.168      0.00
#       5     -1.99112525     0.171      0.00
#       6     -1.99123192     0.008      0.00
#       7     -1.99123192*    0.000      0.00
#  ------------------------------------------------
#  SCF energy                   = -1.81367520
#  ADAPT-VQE correlation energy = -0.17755672
#  ADAPT-VQE energy             = -1.99123192
#
#  ADAPT-VQE calculation: 21.16 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  - 0.70711|11010010> + 0.70711|11100001>
#  |b3> =  + 1.00000|11001100>
#      1      3      0.3625     -1.4965851389     -1.4232029915     -1.3255173450
#      2      6      0.3080     -1.5450409539     -1.4966145616     -1.4399508280
#      3      7      0.0919     -1.7725783109     -1.4966145616     -1.4399508280
#      4      8      0.0249     -1.7852809021     -1.4966145616     -1.4399508280
#      5      9      0.0000     -1.7861099527     -1.4966145616     -1.4399508280
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.786110    5.581640   0.00  - 0.29705|00110011> + 0.45511|00111100> - 0.28243|01011010> + 0.14433|01100110> + 0.13811|01101001> + 0.13811|10010110> + 0.14433|10011001> - 0.28243|10100101> + 0.47139|11000011> - 0.49303|11001100>
#      2   -1.496615   13.459194   0.00  + 0.70702|11011000> - 0.70702|11100100>
#      3   -1.439951   15.001089   0.00  - 0.53513|01111000> + 0.53513|10110100> - 0.46221|11010010> + 0.46221|11100001>
#
#  qEOM-Davidson calculation: 0.30 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  + 0.70711|11010010> + 0.70711|11100001>
#      1      2      0.3138     -1.7180960051     -1.6683024555
#      2      4      0.0000     -1.8911366220     -1.8835306654
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.891137    2.723726   2.00  + 0.43373|01110010> + 0.43373|10110001> - 0.55846|11011000> - 0.55846|11100100>
#      2   -1.883531    2.930694   2.00  + 0.49330|01111000> + 0.49330|10110100> - 0.50661|11010010> - 0.50661|11100001>
#
#  qEOM-Davidson calculation: 0.06 s
#  =====================================================================================
#
# r = 2.40
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -1.86704712     0.463      0.00
#       2     -1.91070454     0.457      0.00
#       3     -1.96060239     0.355      0.00
#       4     -1.97231550     0.169      0.00
#       5     -1.99193118     0.172      0.00
#       6     -1.99201991     0.007      0.00
#       7     -1.99201991*    0.000      0.00
#  ------------------------------------------------
#  SCF energy                   = -1.81489934
#  ADAPT-VQE correlation energy = -0.17712057
#  ADAPT-VQE energy             = -1.99201991
#
#  ADAPT-VQE calculation: 21.17 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  - 0.70711|11010010> + 0.70711|11100001>
#  |b3> =  + 1.00000|11001100>
#      1      3      0.3666     -1.4907038361     -1.4230187741     -1.3131411169
#      2      5      0.3107     -1.5360273921     -1.4907038361     -1.4374812228
#      3      6      0.0948     -1.7709541551     -1.4907038361     -1.4374812228
#      4      7      0.0260     -1.7844055553     -1.4907038361     -1.4374812228
#      5      8      0.0010     -1.7853219334     -1.4907038361     -1.4374812228
#      6      9      0.0000     -1.7853237125     -1.4907038361     -1.4374812228
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.785324    5.624477   0.00  + 0.30512|00110011> - 0.45538|00111100> + 0.28338|01011010> - 0.14431|01100110> - 0.13907|01101001> - 0.13907|10010110> - 0.14431|10011001> + 0.28338|10100101> - 0.47292|11000011> + 0.48470|11001100>
#      2   -1.490704   13.641474   0.00  - 0.70711|11011000> + 0.70711|11100100>
#      3   -1.437481   15.089732   0.00  + 0.53684|01111000> - 0.53684|10110100> + 0.46022|11010010> - 0.46022|11100001>
#
#  qEOM-Davidson calculation: 0.34 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  + 0.70711|11010010> + 0.70711|11100001>
#      1      2      0.3161     -1.7127473713     -1.6672473013
#      2      4      0.0000     -1.8907282764     -1.8843860292
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.890728    2.756279   2.00  + 0.43949|01110010> + 0.43949|10110001> - 0.55394|11011000> - 0.55394|11100100>
#      2   -1.884386    2.928860   2.00  + 0.49359|01111000> + 0.49359|10110100> - 0.50633|11010010> - 0.50633|11100001>
#
#  qEOM-Davidson calculation: 0.06 s
#  =====================================================================================

# %%
print("singlet")
print_result(bond_lengths,singlet)
# Out:
# singlet
# Total Energy
# 1.75  -1.9652631233  -1.8081051439  -1.5871401292  -1.4491152376
# 1.80  -1.9689148382  -1.8064784829  -1.5796812223  -1.4521165865
# 1.85  -1.9723281769  -1.8036770125  -1.5709049775  -1.4536919117
# 1.90  -1.9754617591  -1.8012685770  -1.5625966215  -1.4541919075
# 1.95  -1.9782728236  -1.7988445485  -1.5543566374  -1.4539873006
# 2.00  -1.9807664879  -1.7965381912  -1.5462604805  -1.4532409710
# 2.05  -1.9829603171  -1.7944202097  -1.5383618763  -1.4520702157
# 2.10  -1.9848781650  -1.7925203934  -1.5306991206  -1.4505628987
# 2.15  -1.9865462555  -1.7908441951  -1.5232990530  -1.4487870711
# 2.20  -1.9879911055  -1.7893833916  -1.5161804821  -1.4467967336
# 2.25  -1.9892381735  -1.7881204190  -1.5093552601  -1.4446372171
# 2.30  -1.9903112215  -1.7870362660  -1.5028316873  -1.4423449348
# 2.35  -1.9912319226  -1.7861099527  -1.4966145616  -1.4399508280
# 2.40  -1.9920199071  -1.7853237125  -1.4907038361  -1.4374812228
#
# Excitation Energy
# 1.75   4.2764767864  10.2892275206  14.0450676440
# 1.80   4.4201083881  10.5915622579  14.0627649653
# 1.85   4.5892215738  10.9232569682  14.1127797453
# 1.90   4.7400272149  11.2346072638  14.1844431214
# 1.95   4.8824810318  11.5353209344  14.2665035334
# 2.00   5.0130959754  11.8234839951  14.3546680592
# 2.05   5.1304260578  12.0981124764  14.4462228606
# 2.10   5.2343097573  12.3588133911  14.5394261351
# 2.15   5.3253122844  12.6055699819  14.6331397075
# 2.20   5.4043789641  12.8385920090  14.7266157107
# 2.25   5.4726804970  13.0582497138  14.8193133873
# 2.30   5.5313807906  13.2649638260  14.9108884801
# 2.35   5.5816404993  13.4591935482  15.0010887933
# 2.40   5.6244772400  13.6414743208  15.0897321257

# %%
print("triplet")
print_result(bond_lengths,triplet)
# Out:
# triplet
# Total Energy
# 1.75  -1.9652631233  -1.9021325400  -1.8434999872
# 1.80  -1.9689148382  -1.9010665740  -1.8518607661
# 1.85  -1.9723281769  -1.8994418039  -1.8585898197
# 1.90  -1.9754617591  -1.8984047655  -1.8635290571
# 1.95  -1.9782728236  -1.8973237460  -1.8676000951
# 2.00  -1.9807664879  -1.8962642089  -1.8709855237
# 2.05  -1.9829603171  -1.8952661131  -1.8738177349
# 2.10  -1.9848781650  -1.8943514116  -1.8761965741
# 2.15  -1.9865462555  -1.8935295766  -1.8781995430
# 2.20  -1.9879911055  -1.8928025776  -1.8798885003
# 2.25  -1.9892381735  -1.8921656273  -1.8813135566
# 2.30  -1.9903112215  -1.8916129616  -1.8825161501
# 2.35  -1.9912319226  -1.8911366220  -1.8835306654
# 2.40  -1.9920199071  -1.8907282764  -1.8843860292
#
# Excitation Energy
# 1.75   1.7178667944   3.3133362196
# 1.80   1.8462411385   3.1851963490
# 1.85   1.9833347521   3.0949713537
# 1.90   2.0968228643   3.0458370846
# 1.95   2.2027316240   3.0115515357
# 2.00   2.2994189404   2.9872854482
# 2.05   2.3862754477   2.9699142297
# 2.10   2.4633528699   2.9573700461
# 2.15   2.5311070381   2.9482575580
# 2.20   2.5902059273   2.9416150778
# 2.25   2.6414725641   2.9367717808
# 2.30   2.6857103846   2.9332466740
# 2.35   2.7237257108   2.9306938650
# 2.40   2.7562794400   2.9288603862

# %%
fci_energies = np.array([[-1.965263123,-1.908634752,-1.849795572,-1.818602242,-1.593438758,-1.450829873],
                         [-1.968914838,-1.906152050,-1.855553805,-1.813583235,-1.584203258,-1.452706681],
                         [-1.972338803,-1.903881184,-1.860498878,-1.809010509,-1.575092604,-1.453789849],
                         [-1.975466301,-1.901831712,-1.864740139,-1.804939588,-1.566157831,-1.454196242],
                         [-1.978274757,-1.900003261,-1.868372947,-1.801371968,-1.557439766,-1.454028039],
                         [-1.980767298,-1.898388234,-1.871480470,-1.798280085,-1.548970554,-1.453374521],
                         [-1.982960646,-1.896973923,-1.874135029,-1.795622094,-1.540774819,-1.452313431],
                         [-1.984878291,-1.895744554,-1.876399589,-1.793350847,-1.532870971,-1.450912492],
                         [-1.986546299,-1.894682638,-1.878328745,-1.791418790,-1.525272127,-1.449230438],
                         [-1.987991118,-1.893770289,-1.879969925,-1.789780942,-1.517987213,-1.447318252],
                         [-1.989238176,-1.892989944,-1.881364149,-1.788396124,-1.511021751,-1.445219994],
                         [-1.990311222,-1.892325015,-1.882546933,-1.787227656,-1.504378706,-1.442973732],
                         [-1.991231923,-1.891760110,-1.883548845,-1.786243226,-1.498059111,-1.440612182],
                         [-1.992019909,-1.891281399,-1.884396320,-1.785414899,-1.492062858,-1.438163580]])

# %%
# Plot.
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(0)
plt.plot(bond_lengths, fci_energies[:,0], '--', label='GS', color='black')
plt.plot(bond_lengths, fci_energies[:,1], '--', label='T1', color='red')
plt.plot(bond_lengths, fci_energies[:,2], '--', label='T2', color='green')
plt.plot(bond_lengths, fci_energies[:,3], '--', label='S1', color='blue')
plt.plot(bond_lengths, fci_energies[:,4], '--', label='S2', color='orange')
plt.plot(bond_lengths, fci_energies[:,5], '--', label='S3', color='brown')

plt.plot(bond_lengths, triplet[:,0], 'o', label='GS', color='black')
plt.plot(bond_lengths, triplet[:,1], 'o', label='T1', color='red')
plt.plot(bond_lengths, triplet[:,2], 'o', label='T2', color='green')
plt.plot(bond_lengths, singlet[:,1], 'o', label='S1', color='blue')
plt.plot(bond_lengths, singlet[:,2], 'o', label='S2', color='orange')
plt.plot(bond_lengths, singlet[:,3], 'o', label='S3', color='brown')

plt.ylabel('Energy in Hartree')
plt.xlabel('Bond length in angstrom')
plt.legend()
plt.show()

# %%
# Plot.
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(0)
plt.plot(bond_lengths, abs(fci_energies[:,1]-triplet[:,1])*1000, 'o', label='T1', color='red')
plt.plot(bond_lengths, abs(fci_energies[:,2]-triplet[:,2])*1000, 'o', label='T2', color='green')
plt.plot(bond_lengths, abs(fci_energies[:,3]-singlet[:,1])*1000, 'o', label='S1', color='blue')
plt.plot(bond_lengths, abs(fci_energies[:,4]-singlet[:,2])*1000, 'o', label='S2', color='orange')
plt.plot(bond_lengths, abs(fci_energies[:,5]-singlet[:,3])*1000, 'o', label='S3', color='brown')

plt.ylabel('Error in mHartree')
plt.xlabel('Bond length in angstrom')
plt.legend()
plt.show()
