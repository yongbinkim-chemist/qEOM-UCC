# %%
import numpy as np
import openfermion
from openfermion.chem import MolecularData
from openfermionqchem import run_qchem
import qeom

# %%
def print_result(bond,energy):   
    string1,string2 = "Total Energy\n","Excitation Energy\n"
    
    for i in range(len(bond)):
        string1 += "{:4.2f}".format(bond[i])
        string2 += "{:4.2f}".format(bond[i])

        for j in range(len(energy[i])):
            string1 += "{:15.10f}".format(energy[i][j])
        string1 += '\n'

        for j in range(1,len(energy[i])):
            string2 += "{:15.10f}".format((energy[i][j] - energy[i][0]) * 27.211324570273)
        string2 += '\n'
        
    print(string1+'\n'+string2)

# %% [markdown]
# ## H4/STO-3G

# %%
# Set molecule parameters.
# We do not run calculations through OpenFermion directly.
basis        = 'sto-3g'
multiplicity = 1

# Generate molecule at different bond lengths.
bond_length_interval = 0.05
n_points = 14
singlet  = []
triplet  = []
bond_lengths = []

for point in range(n_points):
    bond_length    = 1.75 + point * bond_length_interval
    geometry       = [('H', (0., 0., 0.)), ('H', (0., 0., bond_length))]
    molecule       = MolecularData(geometry, basis, multiplicity)
    directory      = "/Users/yongbinkim/Desktop/venv/publish/qeom-davidson/OpenFermion-QChem/examples/"
    system         = 'H4/eom-ccsd/sto-3g/'+str(round(bond_length,3)).ljust(4,"0")+'/'
    molecule       = run_qchem(molecule,file_directory=directory+system,output_name='test_qis')

    print("r = {:4.2f}".format(bond_length))
    bond_lengths.append(bond_length)
    
    # ground state
    gs = qeom.Adapt_VQE(molecule)
    gs.run()
    
    qeom_davidson = qeom.Davidson(gs=gs)
    
    # singlet
    user_guess = [[[0,1,2,5],[0,1,3,4]],[[0,1,2,7],[0,1,3,6]],[[0,1,4,5]]]
    qeom_davidson.run(nroot=3,user_guess=user_guess,spin='singlet',level=4)
    singlet.append(qeom_davidson.energy)

    # triplet
    qeom_davidson.run(nroot=2,spin='triplet',level=4)
    triplet.append(qeom_davidson.energy)
    
singlet      = np.array(singlet)
triplet      = np.array(triplet)   
bond_lengths = np.array(bond_lengths)
# Out:
# r = 1.75
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -1.82952518     0.479      0.00
#       2     -1.87614865     0.443      0.00
#       3     -1.92577017     0.336      0.00
#       4     -1.94379515     0.151      0.00
#       5     -1.96292785     0.179      0.00
#       6     -1.96520436     0.036      0.00
#       7     -1.96526312     0.002     -0.00
#       8     -1.96526312*    0.000     -0.00
#  ------------------------------------------------
#  SCF energy                   = -1.76954677
#  ADAPT-VQE correlation energy = -0.19571635
#  ADAPT-VQE energy             = -1.96526312
#
#  ADAPT-VQE calculation: 33.32 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  - 0.70711|11010010> + 0.70711|11100001>
#  |b3> =  + 1.00000|11001100>
#      1      3      0.2851     -1.5859952042     -1.5207989031     -1.3973527970
#      2      6      0.2986     -1.7024794156     -1.5927751640     -1.4112609305
#      3      9      0.0613     -1.8148890652     -1.5933737955     -1.4486459495
#      4     12      0.0096     -1.8185244084     -1.5934387073     -1.4508298019
#      5     13      0.0010     -1.8186012596     -1.5934387073     -1.4508298019
#      6     14      0.0000     -1.8186022888     -1.5934387073     -1.4508298019
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.818602    3.990836   0.00  + 0.12649|00110011> - 0.42478|00111100> + 0.25301|01011010> - 0.18032|01100110> - 0.18032|10011001> + 0.25301|10100101> - 0.44859|11000011> + 0.62475|11001100>
#      2   -1.593439   10.117835   0.00  - 0.70260|11011000> + 0.70260|11100100>
#      3   -1.450830   13.998412   0.00  - 0.53756|01111000> + 0.53756|10110100> - 0.45757|11010010> + 0.45757|11100001>
#
#  qEOM-Davidson calculation: 0.59 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  + 0.70711|01111000> + 0.70711|10110100>
#      1      2      0.2997     -1.7997906077     -1.6415581437
#      2      4      0.1342     -1.8996732749     -1.8363330361
#      3      6      0.0170     -1.9084913349     -1.8495410568
#      4      8      0.0000     -1.9086346848     -1.8497956113
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.908635    1.540935   2.00  + 0.31421|01110010> + 0.31421|10110001> - 0.63008|11011000> - 0.63008|11100100>
#      2   -1.849796    3.142024   2.00  + 0.49077|01111000> + 0.49077|10110100> - 0.50459|11010010> - 0.50459|11100001>
#
#  qEOM-Davidson calculation: 0.24 s
#  =====================================================================================
#
# r = 1.80
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -1.83585836     0.477      0.00
#       2     -1.88221628     0.444      0.00
#       3     -1.93165707     0.337      0.00
#       4     -1.94849654     0.153      0.00
#       5     -1.96725351     0.176      0.00
#       6     -1.96888992     0.030      0.00
#       7     -1.96891484     0.001      0.00
#       8     -1.96891484*    0.000      0.00
#  ------------------------------------------------
#  SCF energy                   = -1.77674732
#  ADAPT-VQE correlation energy = -0.19216752
#  ADAPT-VQE energy             = -1.96891484
#
#  ADAPT-VQE calculation: 33.22 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  - 0.70711|11010010> + 0.70711|11100001>
#  |b3> =  + 1.00000|11001100>
#      1      3      0.2945     -1.5785960517     -1.5047252966     -1.4033617093
#      2      6      0.2976     -1.6832487882     -1.5836648471     -1.4159024458
#      3      9      0.0566     -1.8090778587     -1.5841375458     -1.4525002875
#      4     12      0.0115     -1.8134715829     -1.5842032046     -1.4527066923
#      5     13      0.0000     -1.8135825581     -1.5842032046     -1.4527066923
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.813583    4.226797   0.00  - 0.14851|00110011> + 0.42889|00111100> - 0.25517|01011010> + 0.16891|01100110> + 0.16891|10011001> - 0.25517|10100101> + 0.45322|11000011> - 0.61695|11001100>
#      2   -1.584203   10.468513   0.00  + 0.70371|11011000> - 0.70371|11100100>
#      3   -1.452707   14.046707   0.00  + 0.53665|01111000> - 0.53665|10110100> + 0.45982|11010010> - 0.45982|11100001>
#
#  qEOM-Davidson calculation: 0.49 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  + 0.70711|11010010> + 0.70711|11100001>
#      1      2      0.2979     -1.7919251493     -1.6596153251
#      2      4      0.1126     -1.8972297150     -1.8498116861
#      3      6      0.0112     -1.9060141953     -1.8555122034
#      4      8      0.0000     -1.9061519943     -1.8555537492
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.906152    1.707860   2.00  + 0.32811|01110010> + 0.32811|10110001> - 0.62369|11011000> - 0.62369|11100100>
#      2   -1.855554    3.084705   2.00  + 0.49134|01111000> + 0.49134|10110100> - 0.50589|11010010> - 0.50589|11100001>
#
#  qEOM-Davidson calculation: 0.24 s
#  =====================================================================================
#
# r = 1.85
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -1.84130345     0.475      0.00
#       2     -1.88739947     0.445      0.00
#       3     -1.93670728     0.339      0.00
#       4     -1.95260564     0.154      0.00
#       5     -1.97113325     0.174      0.00
#       6     -1.97232818     0.026     -0.00
#       7     -1.97232818*    0.001     -0.00
#  ------------------------------------------------
#  SCF energy                   = -1.78300199
#  ADAPT-VQE correlation energy = -0.18932618
#  ADAPT-VQE energy             = -1.97232818
#
#  ADAPT-VQE calculation: 23.11 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  - 0.70711|11010010> + 0.70711|11100001>
#  |b3> =  + 1.00000|11001100>
#      1      3      0.3178     -1.5704422480     -1.4846723628     -1.4081285612
#      2      6      0.2882     -1.6653830885     -1.5748969561     -1.4188992838
#      3      9      0.0614     -1.8035943902     -1.5750680471     -1.4534799711
#      4     12      0.0152     -1.8088148093     -1.5750925497     -1.4537897870
#      5     13      0.0000     -1.8090108320     -1.5750925497     -1.4537897870
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.809011    4.444081   0.00  - 0.16273|00110011> + 0.43168|00111100> - 0.25491|01011010> + 0.15372|01100110> + 0.10118|01101001> + 0.10118|10010110> + 0.15372|10011001> - 0.25491|10100101> + 0.45567|11000011> - 0.61443|11001100>
#      2   -1.575093   10.809308   0.00  - 0.70482|11011000> + 0.70482|11100100>
#      3   -1.453790   14.110116   0.00  - 0.53553|01111000> + 0.53553|10110100> - 0.46164|11010010> + 0.46164|11100001>
#
#  qEOM-Davidson calculation: 0.50 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  + 0.70711|11010010> + 0.70711|11100001>
#      1      2      0.3012     -1.7810764002     -1.6635343246
#      2      4      0.1115     -1.8940923221     -1.8559411767
#      3      6      0.0107     -1.9037286877     -1.8604862544
#      4      8      0.0000     -1.9038811257     -1.8604988187
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.903881    1.862535   2.00  + 0.34441|01110010> + 0.34441|10110001> - 0.61521|11011000> - 0.61521|11100100>
#      2   -1.860499    3.043025   2.00  + 0.49172|01111000> + 0.49172|10110100> - 0.50679|11010010> - 0.50679|11100001>
#
#  qEOM-Davidson calculation: 0.24 s
#  =====================================================================================
#
# r = 1.90
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -1.84597414     0.473      0.00
#       2     -1.89181306     0.446      0.00
#       3     -1.94103129     0.340      0.00
#       4     -1.95616717     0.156      0.00
#       5     -1.97457552     0.172      0.00
#       6     -1.97546176     0.022     -0.00
#       7     -1.97546176*    0.000     -0.00
#  ------------------------------------------------
#  SCF energy                   = -1.78842885
#  ADAPT-VQE correlation energy = -0.18703291
#  ADAPT-VQE energy             = -1.97546176
#
#  ADAPT-VQE calculation: 21.64 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  - 0.70711|11010010> + 0.70711|11100001>
#  |b3> =  + 1.00000|11001100>
#      1      3      0.3233     -1.5620900659     -1.4665475532     -1.4119680341
#      2      6      0.2887     -1.6508452465     -1.5659539416     -1.4212528314
#      3      9      0.0690     -1.7988240982     -1.5661331844     -1.4527130416
#      4     12      0.0171     -1.8046864946     -1.5661577770     -1.4541961902
#      5     13      0.0000     -1.8049394600     -1.5661577770     -1.4541961902
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.804939    4.640138   0.00  + 0.18206|00110011> - 0.43542|00111100> + 0.25918|01011010> - 0.15055|01100110> - 0.10863|01101001> - 0.10863|10010110> - 0.15055|10011001> + 0.25918|10100101> - 0.45908|11000011> + 0.60018|11001100>
#      2   -1.566158   11.137704   0.00  - 0.70499|11011000> + 0.70499|11100100>
#      3   -1.454196   14.184327   0.00  - 0.53438|01111000> + 0.53438|10110100> - 0.46307|11010010> + 0.46307|11100001>
#
#  qEOM-Davidson calculation: 0.49 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  + 0.70711|11010010> + 0.70711|11100001>
#      1      2      0.3014     -1.7745846446     -1.6663141857
#      2      4      0.1052     -1.8925084076     -1.8613681682
#      3      6      0.0100     -1.9016926364     -1.8647362299
#      4      8      0.0000     -1.9018316364     -1.8647400704
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.901832    2.003573   2.00  + 0.35554|01110010> + 0.35554|10110001> - 0.60938|11011000> - 0.60938|11100100>
#      2   -1.864740    3.012884   2.00  + 0.49180|01111000> + 0.49180|10110100> - 0.50721|11010010> - 0.50721|11100001>
#
#  qEOM-Davidson calculation: 0.24 s
#  =====================================================================================
#
# r = 1.95
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -1.84997035     0.471      0.00
#       2     -1.89555788     0.447      0.00
#       3     -1.94472578     0.342      0.00
#       4     -1.95923341     0.157      0.00
#       5     -1.97760568     0.171      0.00
#       6     -1.97827282     0.020      0.00
#       7     -1.97827282*    0.000      0.00
#  ------------------------------------------------
#  SCF energy                   = -1.79313192
#  ADAPT-VQE correlation energy = -0.18514091
#  ADAPT-VQE energy             = -1.97827282
#
#  ADAPT-VQE calculation: 21.41 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  - 0.70711|11010010> + 0.70711|11100001>
#  |b3> =  + 1.00000|11001100>
#      1      3      0.3287     -1.5538465840     -1.4486118955     -1.4150426017
#      2      6      0.2896     -1.6368787485     -1.5572335666     -1.4228901060
#      3      9      0.0772     -1.7945308816     -1.5574173454     -1.4509652878
#      4     12      0.0189     -1.8010504470     -1.5574397120     -1.4540280116
#      5     13      0.0012     -1.8013706358     -1.5574397120     -1.4540280116
#      6     14      0.0000     -1.8013720058     -1.5574397120     -1.4540280116
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.801372    4.813706   0.00  + 0.19932|00110011> - 0.43838|00111100> + 0.26348|01011010> - 0.14854|01100110> - 0.11494|01101001> - 0.11494|10010110> - 0.14854|10011001> + 0.26348|10100101> - 0.46180|11000011> + 0.58596|11001100>
#      2   -1.557440   11.451426   0.00  + 0.70512|11011000> - 0.70512|11100100>
#      3   -1.454028   14.265396   0.00  + 0.53330|01111000> - 0.53330|10110100> + 0.46427|11010010> - 0.46427|11100001>
#
#  qEOM-Davidson calculation: 0.59 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  + 0.70711|11010010> + 0.70711|11100001>
#      1      2      0.3022     -1.7679512441     -1.6683008109
#      2      4      0.0999     -1.8911453679     -1.8658512191
#      3      6      0.0094     -1.8998761901     -1.8683724141
#      4      7      0.0000     -1.9000032186     -1.8683724141
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.900003    2.129820   2.00  + 0.36624|01110010> + 0.36624|10110001> - 0.60341|11011000> - 0.60341|11100100>
#      2   -1.868372    2.990536   2.00  - 0.49183|01111000> - 0.49183|10110100> + 0.50746|11010010> + 0.50746|11100001>
#
#  qEOM-Davidson calculation: 0.22 s
#  =====================================================================================
#
# r = 2.00
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -1.85337994     0.470      0.00
#       2     -1.89872250     0.448      0.00
#       3     -1.94787535     0.343      0.00
#       4     -1.96185797     0.159      0.00
#       5     -1.98025718     0.171      0.00
#       6     -1.98076649     0.017      0.00
#       7     -1.98076649*    0.000      0.00
#  ------------------------------------------------
#  SCF energy                   = -1.79720283
#  ADAPT-VQE correlation energy = -0.18356365
#  ADAPT-VQE energy             = -1.98076649
#
#  ADAPT-VQE calculation: 21.42 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  - 0.70711|11010010> + 0.70711|11100001>
#  |b3> =  + 1.00000|11001100>
#      1      3      0.3338     -1.5457780942     -1.4310599049     -1.4174789853
#      2      6      0.2910     -1.6234822717     -1.5487710068     -1.4240277194
#      3      9      0.0848     -1.7906873533     -1.5489508054     -1.4486665016
#      4     12      0.0206     -1.7978802450     -1.5489705007     -1.4533745656
#      5     13      0.0019     -1.7982764551     -1.5489705007     -1.4533745656
#      6     14      0.0000     -1.7982800097     -1.5489705007     -1.4533745656
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.798280    4.965699   0.00  + 0.21529|00110011> - 0.44122|00111100> + 0.26712|01011010> - 0.14706|01100110> - 0.12007|01101001> - 0.12007|10010110> - 0.14706|10011001> + 0.26712|10100101> - 0.46419|11000011> + 0.57207|11001100>
#      2   -1.548971   11.749741   0.00  + 0.70526|11011000> - 0.70526|11100100>
#      3   -1.453375   14.351033   0.00  - 0.53234|01111000> + 0.53234|10110100> - 0.46528|11010010> + 0.46528|11100001>
#
#  qEOM-Davidson calculation: 0.60 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  + 0.70711|11010010> + 0.70711|11100001>
#      1      2      0.3033     -1.7612769475     -1.6696411597
#      2      4      0.0952     -1.8899867142     -1.8695747443
#      3      6      0.0090     -1.8982717608     -1.8714803915
#      4      7      0.0000     -1.8983881590     -1.8714803915
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.898388    2.241623   2.00  + 0.37646|01110010> + 0.37646|10110001> - 0.59739|11011000> - 0.59739|11100100>
#      2   -1.871480    2.973819   2.00  + 0.49195|01111000> + 0.49195|10110100> - 0.50758|11010010> - 0.50758|11100001>
#
#  qEOM-Davidson calculation: 0.21 s
#  =====================================================================================
# r = 2.05
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -1.85627992     0.469      0.00
#       2     -1.90138448     0.449      0.00
#       3     -1.95055382     0.345      0.00
#       4     -1.96409241     0.160      0.00
#       5     -1.98256637     0.170      0.00
#       6     -1.98296032     0.015     -0.00
#       7     -1.98296032*    0.000     -0.00
#  ------------------------------------------------
#  SCF energy                   = -1.80072223
#  ADAPT-VQE correlation energy = -0.18223809
#  ADAPT-VQE energy             = -1.98296032
#
#  ADAPT-VQE calculation: 21.81 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  - 0.70711|11010010> + 0.70711|11100001>
#  |b3> =  + 1.00000|11001100>
#      1      3      0.3388     -1.5379298344     -1.4193769599     -1.4140222327
#      2      6      0.2928     -1.6106558385     -1.5405912651     -1.4248007347
#      3      9      0.0912     -1.7872533907     -1.5407572414     -1.4460763335
#      4     12      0.0223     -1.7951366676     -1.5407747665     -1.4523134780
#      5     13      0.0025     -1.7956154043     -1.5407747665     -1.4523134780
#      6     14      0.0000     -1.7956220744     -1.5407747665     -1.4523134780
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.795622    5.097722   0.00  + 0.22998|00110011> - 0.44379|00111100> + 0.27032|01011010> - 0.14603|01100110> - 0.12428|01101001> - 0.12428|10010110> - 0.14603|10011001> + 0.27032|10100101> - 0.46619|11000011> + 0.55869|11001100>
#      2   -1.540775   12.032455   0.00  + 0.70540|11011000> - 0.70540|11100100>
#      3   -1.452313   14.439603   0.00  + 0.53153|01111000> - 0.53153|10110100> + 0.46609|11010010> - 0.46609|11100001>
#
#  qEOM-Davidson calculation: 0.60 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  + 0.70711|11010010> + 0.70711|11100001>
#      1      2      0.3048     -1.7546409444     -1.6704497654
#      2      4      0.0911     -1.8890141795     -1.8726814026
#      3      6      0.0087     -1.8968669748     -1.8741342001
#      4      7      0.0000     -1.8969739218     -1.8741342001
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.896974    2.339804   2.00  + 0.38616|01110010> + 0.38616|10110001> - 0.59139|11011000> - 0.59139|11100100>
#      2   -1.874134    2.961303   2.00  + 0.49207|01111000> + 0.49207|10110100> - 0.50760|11010010> - 0.50760|11100001>
#
#  qEOM-Davidson calculation: 0.21 s
#  =====================================================================================
#
# r = 2.10
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -1.85873791     0.468      0.00
#       2     -1.90361186     0.450      0.00
#       3     -1.95282568     0.346      0.00
#       4     -1.96598483     0.162      0.00
#       5     -1.98456967     0.170      0.00
#       6     -1.98487817     0.013      0.00
#       7     -1.98487817*    0.000      0.00
#  ------------------------------------------------
#  SCF energy                   = -1.80376100
#  ADAPT-VQE correlation energy = -0.18111716
#  ADAPT-VQE energy             = -1.98487817
#
#  ADAPT-VQE calculation: 21.32 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  - 0.70711|11010010> + 0.70711|11100001>
#  |b3> =  + 1.00000|11001100>
#      1      3      0.3436     -1.5303326395     -1.4208176353     -1.3975842790
#      2      6      0.2949     -1.5983974248     -1.5327116805     -1.4252898881
#      3      9      0.0964     -1.7841841072     -1.5328547800     -1.4433399017
#      4     12      0.0237     -1.7927749406     -1.5328709186     -1.4509124844
#      5     13      0.0032     -1.7933401448     -1.5328709186     -1.4509124844
#      6     14      0.0000     -1.7933506509     -1.5328709186     -1.4509124844
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.793351    5.211717   0.00  + 0.24350|00110011> - 0.44612|00111100> + 0.27309|01011010> - 0.14533|01100110> - 0.12776|01101001> - 0.12776|10010110> - 0.14533|10011001> + 0.27309|10100101> - 0.46785|11000011> + 0.54595|11001100>
#      2   -1.532871   12.299716   0.00  + 0.70555|11011000> - 0.70555|11100100>
#      3   -1.450912   14.529913   0.00  - 0.53089|01111000> + 0.53089|10110100> - 0.46671|11010010> + 0.46671|11100001>
#
#  qEOM-Davidson calculation: 0.59 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  + 0.70711|11010010> + 0.70711|11100001>
#      1      2      0.3064     -1.7481037609     -1.6708184734
#      2      4      0.0875     -1.8882084264     -1.8752818944
#      3      6      0.0084     -1.8956459800     -1.8763974472
#      4      8      0.0000     -1.8957444852     -1.8763995670
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.895744    2.425445   2.00  + 0.39531|01110010> + 0.39531|10110001> - 0.58549|11011000> - 0.58549|11100100>
#      2   -1.876400    2.951846   2.00  - 0.49219|01111000> - 0.49219|10110100> + 0.50754|11010010> + 0.50754|11100001>
#
#  qEOM-Davidson calculation: 0.26 s
#  =====================================================================================
#
# r = 2.15
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -1.86081308     0.467      0.00
#       2     -1.90546409     0.451      0.00
#       3     -1.95474711     0.348      0.00
#       4     -1.96757908     0.163      0.00
#       5     -1.98630188     0.170      0.00
#       6     -1.98654626     0.012      0.00
#       7     -1.98654626*    0.000      0.00
#  ------------------------------------------------
#  SCF energy                   = -1.80638141
#  ADAPT-VQE correlation energy = -0.18016484
#  ADAPT-VQE energy             = -1.98654626
#
#  ADAPT-VQE calculation: 21.27 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  - 0.70711|11010010> + 0.70711|11100001>
#  |b3> =  + 1.00000|11001100>
#      1      3      0.3483     -1.5230067395     -1.4218684670     -1.3817984010
#      2      6      0.2974     -1.5867017020     -1.5251433691     -1.4255463045
#      3      9      0.1003     -1.7814358404     -1.5252566247     -1.4405402750
#      4     12      0.0250     -1.7907506045     -1.5252720757     -1.4492304230
#      5     13      0.0038     -1.7914038747     -1.5252720757     -1.4492304230
#      6     14      0.0000     -1.7914186874     -1.5252720757     -1.4492304230
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.791419    5.309680   0.00  + 0.25597|00110011> - 0.44822|00111100> + 0.27549|01011010> - 0.14487|01100110> - 0.13062|01101001> - 0.13062|10010110> - 0.14487|10011001> + 0.27549|10100101> - 0.46918|11000011> + 0.53393|11001100>
#      2   -1.525272   12.551881   0.00  - 0.70572|11011000> + 0.70572|11100100>
#      3   -1.449230   14.621076   0.00  + 0.53045|01111000> - 0.53045|10110100> + 0.46711|11010010> - 0.46711|11100001>
#
#  qEOM-Davidson calculation: 0.64 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  + 0.70711|11010010> + 0.70711|11100001>
#      1      2      0.3082     -1.7417103926     -1.6708223868
#      2      4      0.0842     -1.8875502270     -1.8774638152
#      3      6      0.0081     -1.8945916475     -1.8783253354
#      4      8      0.0000     -1.8946825629     -1.8783287194
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.894683    2.499733   2.00  + 0.40389|01110010> + 0.40389|10110001> - 0.57974|11011000> - 0.57974|11100100>
#      2   -1.878329    2.944742   2.00  + 0.49237|01111000> + 0.49237|10110100> - 0.50743|11010010> - 0.50743|11100001>
#
#  qEOM-Davidson calculation: 0.24 s
#  =====================================================================================
#
# r = 2.20
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -1.86255726     0.466      0.00
#       2     -1.90699324     0.452      0.00
#       3     -1.95636703     0.349      0.00
#       4     -1.96891466     0.164      0.00
#       5     -1.98779540     0.170      0.00
#       6     -1.98799111     0.011      0.00
#       7     -1.98799111*    0.000      0.00
#  ------------------------------------------------
#  SCF energy                   = -1.80863808
#  ADAPT-VQE correlation energy = -0.17935302
#  ADAPT-VQE energy             = -1.98799111
#
#  ADAPT-VQE calculation: 21.03 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  - 0.70711|11010010> + 0.70711|11100001>
#  |b3> =  + 1.00000|11001100>
#      1      3      0.3527     -1.5159648392     -1.4225861723     -1.3666949749
#      2      6      0.2999     -1.5755621499     -1.5178925163     -1.4256056530
#      3      9      0.1031     -1.7789675362     -1.5179721194     -1.4377312639
#      4     12      0.0262     -1.7890205309     -1.5179871605     -1.4473182003
#      5     13      0.0044     -1.7897615138     -1.5179871605     -1.4473182003
#      6     14      0.0000     -1.7897808574     -1.5179871605     -1.4473182003
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.789781    5.393563   0.00  + 0.26748|00110011> - 0.45011|00111100> + 0.27754|01011010> - 0.14456|01100110> - 0.13299|01101001> - 0.13299|10010110> - 0.14456|10011001> + 0.27754|10100101> - 0.47024|11000011> + 0.52265|11001100>
#      2   -1.517987   12.789430   0.00  + 0.70589|11011000> - 0.70589|11100100>
#      3   -1.447318   14.712426   0.00  - 0.53022|01111000> + 0.53022|10110100> - 0.46729|11010010> + 0.46729|11100001>
#
#  qEOM-Davidson calculation: 0.59 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  + 0.70711|11010010> + 0.70711|11100001>
#      1      2      0.3101     -1.7354939264     -1.6705240525
#      2      4      0.0812     -1.8870211732     -1.8792971075
#      3      6      0.0079     -1.8936862370     -1.8799654567
#      4      8      0.0000     -1.8937702578     -1.8799698833
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.893770    2.563874   2.00  + 0.41191|01110010> + 0.41191|10110001> - 0.57418|11011000> - 0.57418|11100100>
#      2   -1.879970    2.939401   2.00  - 0.49257|01111000> - 0.49257|10110100> + 0.50726|11010010> + 0.50726|11100001>
#
#  qEOM-Davidson calculation: 0.23 s
#  =====================================================================================
#
# r = 2.25
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -1.86401571     0.465      0.00
#       2     -1.90824474     0.453      0.00
#       3     -1.95772799     0.351      0.00
#       4     -1.97002679     0.165      0.00
#       5     -1.98907982     0.171      0.00
#       6     -1.98923817     0.010      0.00
#       7     -1.98923817*    0.000      0.00
#  ------------------------------------------------
#  SCF energy                   = -1.81057888
#  ADAPT-VQE correlation energy = -0.17865929
#  ADAPT-VQE energy             = -1.98923817
#
#  ADAPT-VQE calculation: 20.93 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  - 0.70711|11010010> + 0.70711|11100001>
#  |b3> =  + 1.00000|11001100>
#      1      3      0.3570     -1.5092129955     -1.4230208893     -1.3522813595
#      2      6      0.3025     -1.5649610881     -1.5109612106     -1.4254983596
#      3      9      0.1046     -1.7767414952     -1.5110076809     -1.4349786867
#      4     12      0.0272     -1.7875448920     -1.5110216994     -1.4452199579
#      5     13      0.0049     -1.7883720085     -1.5110216994     -1.4452199579
#      6     14      0.0000     -1.7883958935     -1.5110216994     -1.4452199579
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.788396    5.465184   0.00  - 0.27809|00110011> + 0.45182|00111100> - 0.27930|01011010> + 0.14436|01100110> + 0.13494|01101001> + 0.13494|10010110> + 0.14436|10011001> - 0.27930|10100101> + 0.47106|11000011> - 0.51213|11001100>
#      2   -1.511022   13.012904   0.00  + 0.70607|11011000> - 0.70607|11100100>
#      3   -1.445220   14.803456   0.00  + 0.53025|01111000> - 0.53025|10110100> + 0.46719|11010010> - 0.46719|11100001>
#
#  qEOM-Davidson calculation: 0.58 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  + 0.70711|11010010> + 0.70711|11100001>
#      1      2      0.3121     -1.7294765324     -1.6699759889
#      2      4      0.0785     -1.8866021692     -1.8808388850
#      3      6      0.0077     -1.8929121033     -1.8813589556
#      4      8      0.0000     -1.8929898493     -1.8813641099
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.892990    2.619044   2.00  + 0.41936|01110010> + 0.41936|10110001> - 0.56884|11011000> - 0.56884|11100100>
#      2   -1.881364    2.935396   2.00  - 0.49280|01111000> - 0.49280|10110100> + 0.50706|11010010> + 0.50706|11100001>
#
#  qEOM-Davidson calculation: 0.23 s
#  =====================================================================================
#
# r = 2.30
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -1.86522797     0.464      0.00
#       2     -1.90925821     0.454      0.00
#       3     -1.95886693     0.352      0.00
#       4     -1.97094662     0.167      0.00
#       5     -1.99018185     0.171      0.00
#       6     -1.99031122     0.009      0.00
#       7     -1.99031122*    0.000      0.00
#  ------------------------------------------------
#  SCF energy                   = -1.81224571
#  ADAPT-VQE correlation energy = -0.17806551
#  ADAPT-VQE energy             = -1.99031122
#
#  ADAPT-VQE calculation: 20.85 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  - 0.70711|11010010> + 0.70711|11100001>
#  |b3> =  + 1.00000|11001100>
#      1      3      0.3612     -1.5027535610     -1.4232143007     -1.3385587795
#      2      6      0.3052     -1.5548867200     -1.5043482592     -1.4252475449
#      3      9      0.1051     -1.7747259594     -1.5043681134     -1.4323431796
#      4     12      0.0282     -1.7862884129     -1.5043786542     -1.4429737322
#      5     13      0.0053     -1.7871991469     -1.5043786542     -1.4429737322
#      6     14      0.0000     -1.7872274051     -1.5043786542     -1.4429737322
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.787227    5.526180   0.00  + 0.28787|00110011> - 0.45336|00111100> + 0.28080|01011010> - 0.14424|01100110> - 0.13656|01101001> - 0.13656|10010110> - 0.14424|10011001> + 0.28080|10100101> - 0.47167|11000011> + 0.50235|11001100>
#      2   -1.504379   13.222869   0.00  - 0.70623|11011000> + 0.70623|11100100>
#      3   -1.442974   14.893778   0.00  - 0.53059|01111000> + 0.53059|10110100> - 0.46676|11010010> + 0.46676|11100001>
#
#  qEOM-Davidson calculation: 0.59 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  + 0.70711|11010010> + 0.70711|11100001>
#      1      2      0.3141     -1.7236740682     -1.6692228254
#      2      4      0.0760     -1.8862772125     -1.8821357715
#      3      6      0.0074     -1.8922529508     -1.8825413265
#      4      8      0.0000     -1.8923249242     -1.8825468757
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.892325    2.666337   2.00  + 0.42627|01110010> + 0.42627|10110001> - 0.56375|11011000> - 0.56375|11100100>
#      2   -1.882547    2.932411   2.00  - 0.49306|01111000> - 0.49306|10110100> + 0.50683|11010010> + 0.50683|11100001>
#
#  qEOM-Davidson calculation: 0.23 s
#  =====================================================================================
#
# r = 2.35
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -1.86622843     0.464      0.00
#       2     -1.91006813     0.455      0.00
#       3     -1.95981582     0.354      0.00
#       4     -1.97170152     0.168      0.00
#       5     -1.99112525     0.171      0.00
#       6     -1.99123192     0.008      0.00
#       7     -1.99123192*    0.000      0.00
#  ------------------------------------------------
#  SCF energy                   = -1.81367520
#  ADAPT-VQE correlation energy = -0.17755672
#  ADAPT-VQE energy             = -1.99123192
#
#  ADAPT-VQE calculation: 20.92 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  - 0.70711|11010010> + 0.70711|11100001>
#  |b3> =  + 1.00000|11001100>
#      1      3      0.3652     -1.4965851389     -1.4232029915     -1.3255173450
#      2      6      0.3079     -1.5453222708     -1.4980497705     -1.4248743644
#      3      9      0.1047     -1.7728926360     -1.4980553556     -1.4299007139
#      4     11      0.0290     -1.7852191414     -1.4980553556     -1.4406121872
#      5     12      0.0057     -1.7862104854     -1.4980553556     -1.4406121872
#      6     13      0.0000     -1.7862428085     -1.4980553556     -1.4406121872
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.786243    5.578025   0.00  + 0.29690|00110011> - 0.45474|00111100> + 0.28207|01011010> - 0.14417|01100110> - 0.13790|01101001> - 0.13790|10010110> - 0.14417|10011001> + 0.28207|10100101> - 0.47211|11000011> + 0.49329|11001100>
#      2   -1.498055   13.419988   0.00  + 0.70638|11011000> - 0.70638|11100100>
#      3   -1.440612   14.983092   0.00  - 0.53130|01111000> + 0.53130|10110100> - 0.46591|11010010> + 0.46591|11100001>
#
#  qEOM-Davidson calculation: 0.56 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  + 0.70711|11010010> + 0.70711|11100001>
#      1      2      0.3162     -1.7180960051     -1.6683024555
#      2      4      0.0737     -1.8860312005     -1.8832264676
#      3      6      0.0072     -1.8916934908     -1.8835431952
#      4      8      0.0000     -1.8917601198     -1.8835488242
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.891760    2.706760   2.00  + 0.43265|01110010> + 0.43265|10110001> - 0.55891|11011000> - 0.55891|11100100>
#      2   -1.883549    2.930200   2.00  - 0.49333|01111000> - 0.49333|10110100> + 0.50657|11010010> + 0.50657|11100001>
#
#  qEOM-Davidson calculation: 0.24 s
#  =====================================================================================
#
# r = 2.40
# *****************************************************
# *              Start ADAPT-VQE algorithm            *
# * Grimsley, H.R., Economou, S.E., Barnes, E. et al. *
# *              Nat Commun 10, 3007 (2019).          *
# *     https://doi.org/10.1038/s41467-019-10988-2    *
# *       https://github.com/asthanaa/adapt-vqe       *
# *****************************************************
#  ------------------------------------------------
#       Iter   Energy (a.u.)  Gnorm      <S^2>
#  ------------------------------------------------
#       1     -1.86704712     0.463      0.00
#       2     -1.91070454     0.457      0.00
#       3     -1.96060239     0.355      0.00
#       4     -1.97231550     0.169      0.00
#       5     -1.99193118     0.172      0.00
#       6     -1.99201991     0.007      0.00
#       7     -1.99201991*    0.000      0.00
#  ------------------------------------------------
#  SCF energy                   = -1.81489934
#  ADAPT-VQE correlation energy = -0.17712057
#  ADAPT-VQE energy             = -1.99201991
#
#  ADAPT-VQE calculation: 20.64 s
#  ================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  - 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  - 0.70711|11010010> + 0.70711|11100001>
#  |b3> =  + 1.00000|11001100>
#      1      3      0.3691     -1.4907038361     -1.4230187741     -1.3131411169
#      2      6      0.3105     -1.5362499909     -1.4920598789     -1.4243975155
#      3      9      0.1040     -1.7712181806     -1.4920626616     -1.4277240349
#      4     11      0.0297     -1.7843099613     -1.4920626616     -1.4381635199
#      5     12      0.0060     -1.7853787014     -1.4920626616     -1.4381635199
#      6     13      0.0000     -1.7854146821     -1.4920626616     -1.4381635199
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.785415    5.622002   0.00  + 0.30523|00110011> - 0.45599|00111100> + 0.28314|01011010> - 0.14413|01100110> - 0.13901|01101001> - 0.13901|10010110> - 0.14413|10011001> + 0.28314|10100101> - 0.47239|11000011> + 0.48492|11001100>
#      2   -1.492063   13.604499   0.00  + 0.70644|11011000> - 0.70644|11100100>
#      3   -1.438164   15.071166   0.00  - 0.53252|01111000> + 0.53252|10110100> - 0.46451|11010010> + 0.46451|11100001>
#
#  qEOM-Davidson calculation: 0.56 s
#  =====================================================================================
#
# *****************************************************
# *           Start qEOM-DAVIDSON algorithm           *
# *          Yongbin Kim and Anna I. Krylov           *
# *****************************************************
# --------------------------------------------------------------------------------
#      Iter   NVecs  ResNorm     Total energy (a.u.)
# --------------------------------------------------------------------------------
#  Initial guess vectors
#  |b1> =  + 0.70711|11011000> + 0.70711|11100100>
#  |b2> =  + 0.70711|11010010> + 0.70711|11100001>
#      1      2      0.3182     -1.7127473713     -1.6672473013
#      2      4      0.0716     -1.8858505229     -1.8841432414
#      3      6      0.0069     -1.8912196775     -1.8843909348
#      4      8      0.0000     -1.8912813324     -1.8843963622
#  -------------------------------------------------------------------------------------
#    Root #    a.u.       eV       <S^2>    Wavefunction
#  -------------------------------------------------------------------------------------
#      1   -1.891281    2.741230   2.00  + 0.43854|01110010> + 0.43854|10110001> - 0.55434|11011000> - 0.55434|11100100>
#      2   -1.884396    2.928579   2.00  - 0.49361|01111000> - 0.49361|10110100> + 0.50630|11010010> + 0.50630|11100001>
#
#  qEOM-Davidson calculation: 0.23 s
#  =====================================================================================

# %%
print("singlet")
print_result(bond_lengths,singlet)
# Out:
# singlet
# Total Energy
# 1.75  -1.9652631233  -1.8186022888  -1.5934387073  -1.4508298019
# 1.80  -1.9689148382  -1.8135825581  -1.5842032046  -1.4527066923
# 1.85  -1.9723281769  -1.8090108320  -1.5750925497  -1.4537897870
# 1.90  -1.9754617591  -1.8049394600  -1.5661577770  -1.4541961902
# 1.95  -1.9782728236  -1.8013720058  -1.5574397120  -1.4540280116
# 2.00  -1.9807664879  -1.7982800097  -1.5489705007  -1.4533745656
# 2.05  -1.9829603171  -1.7956220744  -1.5407747665  -1.4523134780
# 2.10  -1.9848781650  -1.7933506509  -1.5328709186  -1.4509124844
# 2.15  -1.9865462555  -1.7914186874  -1.5252720757  -1.4492304230
# 2.20  -1.9879911055  -1.7897808574  -1.5179871605  -1.4473182003
# 2.25  -1.9892381735  -1.7883958935  -1.5110216994  -1.4452199579
# 2.30  -1.9903112215  -1.7872274051  -1.5043786542  -1.4429737322
# 2.35  -1.9912319226  -1.7862428085  -1.4980553556  -1.4406121872
# 2.40  -1.9920199071  -1.7854146821  -1.4920626616  -1.4381635199
#
# Excitation Energy
# 1.75   3.9908355698  10.1178348670  13.9984120794
# 1.80   4.2267970900  10.4685131301  14.0467074058
# 1.85   4.4440812797  10.8093075822  14.1101164309
# 1.90   4.6401376268  11.1377035047  14.1843265834
# 1.95   4.8137055714  11.4514263898  14.2653957331
# 2.00   4.9656987868  11.7497407552  14.3510327727
# 2.05   5.0977217278  12.0324545383  14.4396033715
# 2.10   5.2117173498  12.2997158907  14.5299134450
# 2.15   5.3096795862  12.5518814226  14.6210755151
# 2.20   5.3935633956  12.7894298976  14.7124259100
# 2.25   5.4651844701  13.0129036931  14.8034562386
# 2.30   5.5261796419  13.2228688063  14.8937780703
# 2.35   5.5780253157  13.4199876339  14.9830923345
# 2.40   5.6220018358  13.6044988812  15.0711659199

# %%
print("triplet")
print_result(bond_lengths,triplet)
# Out:
# triplet
# Total Energy
# 1.75  -1.9652631233  -1.9086346848  -1.8497956113
# 1.80  -1.9689148382  -1.9061519943  -1.8555537492
# 1.85  -1.9723281769  -1.9038811257  -1.8604988187
# 1.90  -1.9754617591  -1.9018316364  -1.8647400704
# 1.95  -1.9782728236  -1.9000032186  -1.8683724141
# 2.00  -1.9807664879  -1.8983881590  -1.8714803915
# 2.05  -1.9829603171  -1.8969739218  -1.8741342001
# 2.10  -1.9848781650  -1.8957444852  -1.8763995670
# 2.15  -1.9865462555  -1.8946825629  -1.8783287194
# 2.20  -1.9879911055  -1.8937702578  -1.8799698833
# 2.25  -1.9892381735  -1.8929898493  -1.8813641099
# 2.30  -1.9903112215  -1.8923249242  -1.8825468757
# 2.35  -1.9912319226  -1.8917601198  -1.8835488242
# 2.40  -1.9920199071  -1.8912813324  -1.8843963622
#
# Excitation Energy
# 1.75   1.5409348215   3.1420239483
# 1.80   1.7078601176   3.0847053882
# 1.85   1.8625349275   3.0430249618
# 1.90   2.0035731678   3.0128838086
# 1.95   2.1298196251   2.9905357132
# 2.00   2.2416234453   2.9738194389
# 2.05   2.3398037120   2.9613027918
# 2.10   2.4254454915   2.9518463390
# 2.15   2.4997327558   2.9447424981
# 2.20   2.5638740673   2.9394005386
# 2.25   2.6190443901   2.9353961583
# 2.30   2.6663369370   2.9324105896
# 2.35   2.7067595123   2.9301997401
# 2.40   2.7412300538   2.9285792137

# %%
fci_energies = np.array([[-1.965263123,-1.908634752,-1.849795572,-1.818602242,-1.593438758,-1.450829873],
                         [-1.968914838,-1.906152050,-1.855553805,-1.813583235,-1.584203258,-1.452706681],
                         [-1.972338803,-1.903881184,-1.860498878,-1.809010509,-1.575092604,-1.453789849],
                         [-1.975466301,-1.901831712,-1.864740139,-1.804939588,-1.566157831,-1.454196242],
                         [-1.978274757,-1.900003261,-1.868372947,-1.801371968,-1.557439766,-1.454028039],
                         [-1.980767298,-1.898388234,-1.871480470,-1.798280085,-1.548970554,-1.453374521],
                         [-1.982960646,-1.896973923,-1.874135029,-1.795622094,-1.540774819,-1.452313431],
                         [-1.984878291,-1.895744554,-1.876399589,-1.793350847,-1.532870971,-1.450912492],
                         [-1.986546299,-1.894682638,-1.878328745,-1.791418790,-1.525272127,-1.449230438],
                         [-1.987991118,-1.893770289,-1.879969925,-1.789780942,-1.517987213,-1.447318252],
                         [-1.989238176,-1.892989944,-1.881364149,-1.788396124,-1.511021751,-1.445219994],
                         [-1.990311222,-1.892325015,-1.882546933,-1.787227656,-1.504378706,-1.442973732],
                         [-1.991231923,-1.891760110,-1.883548845,-1.786243226,-1.498059111,-1.440612182],
                         [-1.992019909,-1.891281399,-1.884396320,-1.785414899,-1.492062858,-1.438163580]])

# %%
# Plot.
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(0)
plt.plot(bond_lengths, fci_energies[:,0], '--', label='GS', color='black')
plt.plot(bond_lengths, fci_energies[:,1], '--', label='T1', color='red')
plt.plot(bond_lengths, fci_energies[:,2], '--', label='T2', color='green')
plt.plot(bond_lengths, fci_energies[:,3], '--', label='S1', color='blue')
plt.plot(bond_lengths, fci_energies[:,4], '--', label='S2', color='orange')
plt.plot(bond_lengths, fci_energies[:,5], '--', label='S3', color='brown')

plt.plot(bond_lengths, triplet[:,0], 'o', label='GS', color='black')
plt.plot(bond_lengths, triplet[:,1], 'o', label='T1', color='red')
plt.plot(bond_lengths, triplet[:,2], 'o', label='T2', color='green')
plt.plot(bond_lengths, singlet[:,1], 'o', label='S1', color='blue')
plt.plot(bond_lengths, singlet[:,2], 'o', label='S2', color='orange')
plt.plot(bond_lengths, singlet[:,3], 'o', label='S3', color='brown')

plt.ylabel('Energy in Hartree')
plt.xlabel('Bond length in angstrom')
plt.legend()
plt.show()

# %%
# Plot.
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(0)
plt.plot(bond_lengths, abs(fci_energies[:,1]-triplet[:,1])*1000, 'o', label='T1', color='red')
plt.plot(bond_lengths, abs(fci_energies[:,2]-triplet[:,2])*1000, 'o', label='T2', color='green')
plt.plot(bond_lengths, abs(fci_energies[:,3]-singlet[:,1])*1000, 'o', label='S1', color='blue')
plt.plot(bond_lengths, abs(fci_energies[:,4]-singlet[:,2])*1000, 'o', label='S2', color='orange')
plt.plot(bond_lengths, abs(fci_energies[:,5]-singlet[:,3])*1000, 'o', label='S3', color='brown')

plt.ylabel('Error in mHartree')
plt.xlabel('Bond length in angstrom')
plt.legend()
plt.show()
